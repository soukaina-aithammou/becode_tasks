# %% [markdown]
# # Alcohol counter

# %% [markdown]
# ### Introduction:
#
# It is all about drinks and indexs.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](http://bit.ly/drinksbycountry).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks

# %%
url='https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv'
drinks=pd.read_csv(url,sep=',')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 6 columns]

# %% [markdown]
# ### Step 4. Print the first 5 rows of the dataframe

# %%
drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ### Step 5. Return the index

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %% [markdown]
# ### Step 6. Identify what rows you are working with

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 6 columns]

# %% [markdown]
# ### Step 7. Use .loc method to retrieve an element/cell

# %%
drinks['beer_servings'].iloc[3]
# Out:
# 245

# %% [markdown]
# ### Step 8. Use .iloc method to retrieve an element/cell

# %%
drinks.iloc[2:5]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 2  Algeria             25                0             14
# 3  Andorra            245              138            312
# 4   Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ### Step 9. Set the index to 'country'

# %%
drinks.set_index('country', inplace=True)
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %% [markdown]
# ### Step 10.Set a more complex index

# %%
idx=drinks.reset_index().set_index(['country','continent'])
idx
# Out:
#                            beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan Asia                       0                0              0
# Albania     Europe                    89              132             54
# Algeria     Africa                    25                0             14
# Andorra     Europe                   245              138            312
# Angola      Africa                   217               57             45
# ...                                  ...              ...            ...
# Venezuela   South America            333              100              3
# Vietnam     Asia                     111                2              1
# Yemen       Asia                       6                0              0
# Zambia      Africa                    32               19              4
# Zimbabwe    Africa                    64               18              4
#
#                            total_litres_of_pure_alcohol
# country     continent
# Afghanistan Asia                                    0.0
# Albania     Europe                                  4.9
# Algeria     Africa                                  0.7
# Andorra     Europe                                 12.4
# Angola      Africa                                  5.9
# ...                                                 ...
# Venezuela   South America                           7.7
# Vietnam     Asia                                    2.0
# Yemen       Asia                                    0.1
# Zambia      Africa                                  2.5
# Zimbabwe    Africa                                  4.7
#
# [193 rows x 4 columns]

# %%
drinks.head(100)
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Lesotho                 82               29              0
# Liberia                 19              152              2
# Libya                    0                0              0
# Lithuania              343              244             56
# Luxembourg             236              133            271
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa
# ...                                   ...       ...
# Lesotho                               2.8    Africa
# Liberia                               3.1    Africa
# Libya                                 0.0    Africa
# Lithuania                            12.9    Europe
# Luxembourg                           11.4    Europe
#
# [100 rows x 5 columns]

# %%
# idx.loc[('Greece','Europe'),'beer_servings']
idx.loc[('Luxembourg','Europe'),'spirit_servings']
# Out:
# 133

# %% [markdown]
# ### Step 11. Clear index name

# %%
drinks.index.name=None
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %% [markdown]
# ### Step 12. Reset index name

# %%
idx.reset_index(inplace=True)

idx
# Out:
#          country      continent  beer_servings  spirit_servings  \
# 0    Afghanistan           Asia              0                0
# 1        Albania         Europe             89              132
# 2        Algeria         Africa             25                0
# 3        Andorra         Europe            245              138
# 4         Angola         Africa            217               57
# ..           ...            ...            ...              ...
# 188    Venezuela  South America            333              100
# 189      Vietnam           Asia            111                2
# 190        Yemen           Asia              6                0
# 191       Zambia         Africa             32               19
# 192     Zimbabwe         Africa             64               18
#
#      wine_servings  total_litres_of_pure_alcohol
# 0                0                           0.0
# 1               54                           4.9
# 2               14                           0.7
# 3              312                          12.4
# 4               45                           5.9
# ..             ...                           ...
# 188              3                           7.7
# 189              1                           2.0
# 190              0                           0.1
# 191              4                           2.5
# 192              4                           4.7
#
# [193 rows x 6 columns]

# %% [markdown]
# ### Step 13. Use the index to select values from series

# %%
idx.head(50)
# Out:
#                      country      continent  beer_servings  spirit_servings  \
# 0                Afghanistan           Asia              0                0
# 1                    Albania         Europe             89              132
# 2                    Algeria         Africa             25                0
# 3                    Andorra         Europe            245              138
# 4                     Angola         Africa            217               57
# 5          Antigua & Barbuda  North America            102              128
# 6                  Argentina  South America            193               25
# 7                    Armenia         Europe             21              179
# 8                  Australia        Oceania            261               72
# 9                    Austria         Europe            279               75
# 10                Azerbaijan         Europe             21               46
# 11                   Bahamas  North America            122              176
# 12                   Bahrain           Asia             42               63
# 13                Bangladesh           Asia              0                0
# 14                  Barbados  North America            143              173
# 15                   Belarus         Europe            142              373
# 16                   Belgium         Europe            295               84
# 17                    Belize  North America            263              114
# 18                     Benin         Africa             34                4
# 19                    Bhutan           Asia             23                0
# 20                   Bolivia  South America            167               41
# 21        Bosnia-Herzegovina         Europe             76              173
# 22                  Botswana         Africa            173               35
# 23                    Brazil  South America            245              145
# 24                    Brunei           Asia             31                2
# 25                  Bulgaria         Europe            231              252
# 26              Burkina Faso         Africa             25                7
# 27                   Burundi         Africa             88                0
# 28             Cote d'Ivoire         Africa             37                1
# 29                Cabo Verde         Africa            144               56
# 30                  Cambodia           Asia             57               65
# 31                  Cameroon         Africa            147                1
# 32                    Canada  North America            240              122
# 33  Central African Republic         Africa             17                2
# 34                      Chad         Africa             15                1
# 35                     Chile  South America            130              124
# 36                     China           Asia             79              192
# 37                  Colombia  South America            159               76
# 38                   Comoros         Africa              1                3
# 39                     Congo         Africa             76                1
# 40              Cook Islands        Oceania              0              254
# 41                Costa Rica  North America            149               87
# 42                   Croatia         Europe            230               87
# 43                      Cuba  North America             93              137
# 44                    Cyprus         Europe            192              154
# 45            Czech Republic         Europe            361              170
# 46               North Korea           Asia              0                0
# 47                  DR Congo         Africa             32                3
# 48                   Denmark         Europe            224               81
# 49                  Djibouti         Africa             15               44
#
#     wine_servings  total_litres_of_pure_alcohol
# 0               0                           0.0
# 1              54                           4.9
# 2              14                           0.7
# 3             312                          12.4
# 4              45                           5.9
# 5              45                           4.9
# 6             221                           8.3
# 7              11                           3.8
# 8             212                          10.4
# 9             191                           9.7
# 10              5                           1.3
# 11             51                           6.3
# 12              7                           2.0
# 13              0                           0.0
# 14             36                           6.3
# 15             42                          14.4
# 16            212                          10.5
# 17              8                           6.8
# 18             13                           1.1
# 19              0                           0.4
# 20              8                           3.8
# 21              8                           4.6
# 22             35                           5.4
# 23             16                           7.2
# 24              1                           0.6
# 25             94                          10.3
# 26              7                           4.3
# 27              0                           6.3
# 28              7                           4.0
# 29             16                           4.0
# 30              1                           2.2
# 31              4                           5.8
# 32            100                           8.2
# 33              1                           1.8
# 34              1                           0.4
# 35            172                           7.6
# 36              8                           5.0
# 37              3                           4.2
# 38              1                           0.1
# 39              9                           1.7
# 40             74                           5.9
# 41             11                           4.4
# 42            254                          10.2
# 43              5                           4.2
# 44            113                           8.2
# 45            134                          11.8
# 46              0                           0.0
# 47              1                           2.3
# 48            278                          10.4
# 49              3                           1.1

# %%
# idx['spirit_servings'].iloc[49]
drinks['wine_servings'].iloc[4]
# Out:
# 45

# %% [markdown]
# ### Step 14. Sort based on values in the Series

# %%
drinks.value_counts('continent').sort_values()
# Out:
# continent
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# dtype: int64

# %% [markdown]
# ### Bonus: Reindex to Align with Other Objects
