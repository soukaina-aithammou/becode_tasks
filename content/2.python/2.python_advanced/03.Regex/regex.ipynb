# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(re.search(pattern, string))
# Out:
# <re.Match object; span=(1, 2), match=' '>

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))
# Out:
# ['I', 'am', 'fine', '!', 'There', 'are', 'still', '6', 'months', 'left', ':()']

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to[0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to[^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to[^ ^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to[a-zA-Z0-9_].
#
#     \W    No alphanumeric presence[^a-zA-Z0-9_].
#
#     \     Is an escape character

# %% [markdown]
# Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character
# Out:
# <re.Match object; span=(0, 4), match='GREY'>

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)
# Out:
# <re.Match object; span=(0, 4), match='GREY'>
# <re.Match object; span=(0, 4), match='GREY'>

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)
# Out:
# GREY 'S <re.Match object; span=(0, 4), match='GREY'>
# GRAY <re.Match object; span=(0, 4), match='GRAY'>
# GREYISH <re.Match object; span=(0, 4), match='GREY'>
# A GREY None

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y
# Out:
# ['E']

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")
# Out:
# [('R', 'E')]

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall("([0-9]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters
# Out:
# ['7', '220']

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall("([A-z]+)", "Hello I live on the 7th floor of 220 street of sims"))
# Out:
# ['Hello', 'I', 'live', 'on', 'the', 'th', 'floor', 'of', 'street', 'of', 'sims']

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | **Refers to any character.**
# **^** | **Indicates that the beginning of the string must match <br/> (i.e. a string can only match if it starts in the same way, <br /> if it is preceded by spaces or a line break)**
# **$** | **Indicates that the end of the chain must match <br /> (the same remark as above applies, but at the end level).**
# **{n}**|**Indicates that the previous character must be repeated n times.**
# **{n, m}**|**Indicates that the previous character must be repeated between n and m times.**
#  *| **The previous character can be repeated none or several times. <br />For example, ab* may correspond to: a, ab, or a followed by any number of b.**
# **+**|**The previous character can be repeated once or several times. <br/>For example, to ab+ corresponds an a followed by any number of b.**
# **?**|**The previous character can be repeated zero or once.<br /> For example, to ab? correspond ab and a.**
# **\w** | **it corresponds to any alphabetical character, it is equivalent to [a-zA-Z].**
# **\W** | **it corresponds to everything that is not an alphabetical character.**
# **\d** | **it corresponds to any numeric character, i.e. it is equivalent to[0-9].**
# **\D** | **it corresponds to everything that is not a numeric character.**

# %% [markdown]
# ![alt text](http://www.codercaste.com/wp-content/uploads/2013/01/regex.gif)

# %% [markdown]
# ### Some useful resources
# http://www.rexegg.com/regex-quickstart.html
# http://www.dreambank.net/regex.html#examples
# https://pythex.org/ *(Pythex is a real-time regular expression editor for Python, a quick way to test your regular expressions.)*
# https://regex101.com/
# *(Regex101 is online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.)*

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")
# Out:
# Your number : 986433
# The string entered is a number.

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")
# Out:
# The string entered is a number.

# %% [markdown]
# ## Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
import re
s = "sssgdds8sfsfs"
x = re.findall(r"\d", s)
print(x)
# Out:
# ['8']

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
import re
s = "sssgdds-8sfsfs"
x = re.findall(r"-\d", s)
print(x)
# Out:
# ['-8']

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
import re
s = "sssgdds-8s8fsfs"
x = re.findall(r"-?\d", s)
print(x)
# Out:
# ['-8', '8']

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
import re
text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."

x = re.findall(r"\W{1,}[0-9,?\.?]+|[0-9]", text)
print(x)
# Out:
# ['2', '1', ' 3', ' 4,003', ' 100.00']

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
import re
text = "He had prudently disguised himself but was quickly captured by the police."
x=re.findall(r"\w+ly",text)
print(x)
# Out:
# ['prudently', 'quickly']

# %% [markdown]
# **6. License plate number**
# A license plate consists of 2 capital letters, a dash ('-'), 3 digits, a dash ('-') and finally 2 capital letters. Write a script to check that an input string is a license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
import re
plate = input("Enter your license plate number: ")
if re.match(r'\b[A-Z]{2}-\d{3}-\b[A-Z]{2}\b',plate):
    print("good")
else:
    print("Not good")
# Out:
# Enter your license plate number: ASD-123-JKD
# Not good

# %% [markdown]
# **7 . Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is that of an IPv4 address.

# %%
import re
ip = input("Enter your IP address :")
if re.match(r'[0-9]|[1-9][0-9]|1[0-9][0-9]|2[0-4][0-9]|25[0-5]\\.{3}[0-9]|[1-9][0-9]|1[0-9][0-9]|2[0-4][0-9]|25[0-5]',ip):
    print('yes')
else:
    print('no')
# Out:
# Enter your IP address :255.6.0.45
# yes

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
import re
mail = input("Enter your email :")
if re.match(r'[A-z0-9]+@[A-z0-9]+\.[A-z]+',mail):
    print("email")
else:
    print("not email")
# Out:
# Enter your email :souka96@gmail.com
# email

# %% [markdown]
# **9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
password = input("Enter your password :")

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
import re
password = input("Enter your password :")
if re.match(r'^(?=.*?[A-Z])(?=.*?[a-z])(?=.*?[0-9])(?=.*?[#?!@$%^&*-]).{6,}$',password):
    print('correct')
else:
    print('not correct')
# Out:
# Enter your password :ADfg5@
# correct

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
import re
m = re.search(
    "Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))
# Out:
# Olivier
# 32

# %%
# Another Example
m = re.search(
    "^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    "audrey.boulevart@benextcomapgny.com",
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))
# Out:
# audrey
# boulevart
# benextcomapgny
# com

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
import re

# loading and opening the mails' file:

file = open("./data/mail.txt","r") 
mailList = file.readlines()

#print(len(mailList))
#print(mailList[4000])

# creating the lists for each type od data:

firstNameList = []
lastNameList = []
operatoreList = []
zonesList = []

# implementing the pattern that can clean all emails:

mail_pattern = re.compile(r"^(?P<firstName>\w*)[.-](?P<LastName>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)")

# check each email
for each_email in mailList:
    check_step = re.search(mail_pattern,each_email)
    if check_step is not None:
        firstNameList.append(check_step.group("firstName"))
        lastNameList.append(check_step.group("LastName"))
        operatoreList.append(check_step.group("operator"))
        zonesList.append(check_step.group("zone"))

# print("The First Names list is : \n", firstNameList)
print("The last Names list is : \n", lastNameList)
#print("The operators Names list is : \n", operatoreList)
#print("The zone Names list is : \n", zonesList)
#print(len(lastNameList))
#print(len(firstNameList))
#print(len(operatoreList))
#print(len(zonesList))

# file.close()
# print(list_mail)
# Out:
# The last Names list is :
#  ['joe', 'thomas', 'hylan', 'steve', 'mark', 'jack', 'hal', 'yang', 'carl', 'joe', 'victor', 'weiss', 'walter', 'hank', 'carl', 'roger', 'dan', 'alex', 'nuttle', 'tim', 'roberts', 'monte', 'linde', 'larry', 'casal', 'sellon', 'matthew', 'schickowski', 'hal', 'carl', 'dan', 'frank', 'weiss', 'otto', 'myers', 'trusela', 'adam', 'jagtap', 'jack', 'fred', 'haworth', 'george', 'yang', 'john', 'hank', 'aaron', 'schickowski', 'alex', 'schwager', 'victor', 'roger', 'joe', 'roger', 'uddin', 'stahl', 'hal', 'aaron', 'john', 'ventotla', 'nugent', 'mark', 'victor', 'matthew', 'dan', 'vogal', 'soulis', 'paul', 'zeaser', 'jack', 'monte', 'frank', 'larry', 'yates', 'eastman', 'roger', 'trusela', 'edward', 'roger', 'deitz', 'victor', 'fred', 'otto', 'john', 'hank', 'duffman', 'tiernan', 'hal', 'alex', 'john', 'fletcher', 'ty', 'bongard', 'jack', 'fred', 'ty', 'peter', 'monte', 'moore', 'adam', 'darnell', 'peter', 'stahl', 'aaron', 'mccord', 'steve', 'mark', 'fletcher', 'roger', 'jack', 'severson', 'paul', 'frank', 'fietzer', 'matthew', 'frank', 'ben', 'otto', 'tiernan', 'dinkins', 'steve', 'matthew', 'roger', 'carl', 'mark', 'jack', 'woo', 'irwin', 'alex', 'monte', 'stahl', 'mccormack', 'ty', 'ben', 'mark', 'zeller', 'casal', 'adam', 'miller', 'peter', 'roberts', 'matthew', 'walter', 'walter', 'david', 'thomas', 'reyes', 'matthew', 'walter', 'vanderpoel', 'norquist', 'walter', 'mark', 'carl', 'tim', 'weinstein', 'dan', 'jack', 'thomas', 'monte', 'hank', 'steve', 'edward', 'moody', 'weinstein', 'jack', 'matthew', 'sandstrom', 'weinstein', 'jack', 'martin', 'ventotla', 'rice', 'fred', 'edward', 'yocum', 'aaron', 'mark', 'hal', 'deitz', 'matthew', 'roger', 'rogers', 'peter', 'mcginnis', 'steve', 'schwager', 'carl', 'nathan', 'ty', 'alex', 'edward', 'roger', 'john', 'thomas', 'paul', 'carl', 'paul', 'victor', 'hal', 'illingsworth', 'ulrich', 'wagner', 'carl', 'aaron', 'alex', 'roger', 'larry', 'roger', 'hal', 'pettigrew', 'ziegler', 'roger', 'sellon', 'moore', 'john', 'george', 'ebner', 'jack', 'joe', 'otto', 'kalleg', 'edward', 'alex', 'thomas', 'celedon', 'ulrich', 'peter', 'mark', 'leisinger', 'wagle', 'ike', 'monte', 'otto', 'aaron', 'nathan', 'upson', 'nathan', 'victor', 'fletcher', 'alex', 'peter', 'edward', 'john', 'nugent', 'roger', 'cataldi', 'valente', 'ben', 'dan', 'sagar', 'hank', 'bateman', 'roger', 'lulloff', 'hank', 'ben', 'kalleg', 'boyd', 'edward', 'roger', 'deitz', 'matthew', 'lewis', 'thomas', 'paul', 'nuttle', 'peter', 'roger', 'ventotla', 'ike', 'nugent', 'ben', 'schlicht', 'victor', 'davidson', 'soloman', 'joe', 'carl', 'thomas', 'vogal', 'victor', 'thomas', 'monte', 'vogal', 'adam', 'larry', 'orwig', 'davidson', 'george', 'ebner', 'schutz', 'larry', 'david', 'cataldi', 'uflan', 'kaskel', 'upson', 'larry', 'matthew', 'fred', 'paul', 'thomas', 'walter', 'monte', 'soulis', 'frank', 'john', 'ortiz', 'otto', 'steve', 'alex', 'walter', 'larry', 'carl', 'john', 'rice', 'ike', 'hank', 'kaskel', 'leisinger', 'bongard', 'lepage', 'christensen', 'edward', 'linde', 'schiebel', 'ben', 'weinstein', 'larry', 'carl', 'cannon', 'nathan', 'schutz', 'miller', 'ben', 'edward', 'alex', 'ike', 'carl', 'victor', 'doran', 'woo', 'mark', 'larry', 'trussel', 'orwig', 'peter', 'hank', 'kaskel', 'thomas', 'larry', 'celedon', 'carl', 'fred', 'hancock', 'tim', 'adam', 'soulis', 'severson', 'ortiz', 'paul', 'fred', 'aaron', 'victor', 'thomas', 'otto', 'monte', 'mark', 'reamer', 'steve', 'hancock', 'ben', 'ory', 'fred', 'paul', 'larry', 'david', 'walter', 'george', 'matthew', 'mark', 'otto', 'mark', 'hal', 'yates', 'cast', 'larry', 'peter', 'adam', 'victor', 'victor', 'roger', 'aaron', 'ike', 'ty', 'pettigrew', 'monte', 'ferro', 'vail', 'carl', 'frank', 'jack', 'ferry', 'uddin', 'lulloff', 'martin', 'ripka', 'carl', 'matthew', 'edward', 'roger', 'haworth', 'nathan', 'moody', 'wakefield', 'victor', 'thompson', 'casal', 'ventotla', 'adam', 'mark', 'mcginnis', 'jack', 'hank', 'roger', 'schiebel', 'mark', 'peter', 'joe', 'lepage', 'thomas', 'larry', 'doran',  ...

# %% [markdown]
# **12. Another way of doing things.**

# %%
mail = "audrey.boulevart@benextcomapgny.com"
splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

firstName, name, ope, zone
# Out:
# (['audrey'], ['boulevart'], ['benextcomapgny'], ['com'])

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?

# %%
file = open("./data/mail.txt","r") 
NewmailList = file.readlines()

# creating the lists for each type od data:

firstNameList2 = []
lastNameList2 = []
operatoreList2 = []
zonesList2 = []

# to separate each email in two parts:
for eachmail in NewmailList:
    new_string = eachmail.replace(".", " ").replace("-", " ").replace("", " ").split("@").copy()
    print(new_string[0])

    firstNameList2.append(new_string[0].split()[0])
    lastNameList2.append(new_string[0].split()[-1])
    operatoreList2.append(new_string[1].split()[0])
    zonesList2.append(new_string[1].split()[-1])

print(len(lastNameList2))
# Out:
#  v o g a l   r o g e r
#  a i k i n   j o e
#  m o o r e
#  h a l k n u t s o n
#  a l e x n o r q u i s t
#  m a t t h e w l u l l o f f
#  j e n s o n   t h o m a s
#  m a r k 4 4 5 1
#  m o n t e   h y l a n
#  d a n 8 0
#  s c h m i t t   s t e v e
#  k n u t s o n d a n
#  l e p a g e
#  c h a p m a n _ b e n
#  u p s o n 1 5 4 4
#  5 5 2 9 6 6 9 5 9
#  s o l o m a n _ z i e g l e r
#  o r t i z   m a r k
#  a s h w o o n _ h a n k
#  p e t t i g r e w
#  d o r a n e d w a r d
#  m i l l s _ j o e
#  v a l e n t e _ a l e x
#  y a n g
#  i k e
#  h a n k s h a f f e r
#  l a r r y t r e b i l
#  d a v i s _ i k e
#  d a v i d s o n h a l
#  j o h n 8 7 3 3
#  j o h n f l e t c h e r
#  c a t a l d i _ l a r r y
#  r o g e r f i e t z e r
#  e d w a r d 4 1 8 5
#  h a n c o c k _ m a t t h e w
#  s o l b e r g _ c a s t
#  v a d e r   j a c k
#  g e o r g e p a k
#  c a s w e l l   h a l
#  i k e
#  t a p i a _ q u i n n
#  7 9 5 4 1 9 8 6 0
#  c h a m b e r s _ j o h n s e n
#  j a c k
#  j o e
#  r e y e s a a r o n
#  b e n   y a n g
#  p e t t i g r e w g e o r g e
#  m i l l e r   p e t e r
#  l i n d e   c a r l
#  b o y d _ c a r l
#  y o c u m _ m a r k
#  d a v i d f e r r o
#  g e o r g e 5 9
#  j o h n s e n 2 2 0 1
#  t h o m p s o n _ a d a m
#  s c h u t z l a r r y
#  q u i z o z   j o e
#  m a t t h e w 8 2 2 7
#  a l e x
#  g e o r g e m o o d y
#  l a w i c k i 5 8 9
#  d o r a n 7 9 4 7
#  b a u e r a a r o n
#  m a r k
#  w a l t e r m a r t i n
#  k a s k e l
#  r o b e r t s _ m a t t h e w
#  g e o r g e
#  f e r r y   v i c t o r
#  f r e d   w e i s s
#  j u r g e n s o n p e t e r
#  s t e v e f i e t z e r
#  s o n d e r l i n g _ c a s w e l l
#  j o h n s e n   w a l t e r
#  m c c o r m a c k
#  r o b e r t s   h a n k
#  v a l e n t e
#  o r y _ w a l t e r
#  t y i r w i n
#  p a u l f e r r y
#  g e o r g e
#  f r a n k   l u l l o f f
#  r i p k a 6 5 9 6
#  w a g n e r _ s c h u s t e r
#  m c c o r m a c k   c a r l
#  8 5 1 8 8 6 7 9 2
#  z e a s e r _ a a r o n
#  a d a m
#  t i s l e r   r o g e r
#  f e r r o   d a n
#  r e a r d o n   a l e x
#  s e v e r s o n _ g e o r g e
#  o t t o   n u t t l e
#  i l l i n g s w o r t h
#  d a n f l e t c h e r
#  a l e x 6 8 5
#  h a n c o c k _ v a l e n t e
#  c a r l 7 8 8 4
#  p a u l 9 5 8 1
#  s a w y e r _ c h a m b e r s
#  j o h n s e n   t i m
#  a a r o n   r o b e r t s
#  s c h i e b e l 2 3 9 2
#  m c c o r m a c k e d w a r d
#  t a p i a 1 8 7 6
#  q u i z o z 9 6 2 8
#  r o g e r s t a h l
#  s c h u t z _ j o h n s e n
#  s c h u t z   m o n t e
#  c a r l u p s o n
#  l a r r y 3 4 9
#  m a t t h e w   l i n d e
#  m c g i n n i s
#  k a l l e g   m o n t e
#  n u g e n t _ j a c k
#  w a g l e _ j o h n
#  c h a p m a n n a t h a n
#  c h r i s t e n s e n   l a r r y
#  h a l 5 3 6
#  4 7 2 5 1 0 7 0 7
#  t h o m a s   c a s a l
#  a d a m i l l i n g s w o r t h
#  w e i s s   a d a m
#  p e t e r s t a h l
#  v i c t o r t a n d y
#  f r e d t u r c o
#  a d a m   s e l l o n
#  v a d e r   m a t t h e w
#  i k e 3 8 3 1
#  t i m f l e t c h e r
#  f r a n k   s c h i c k o w s k i
#  5 6 6 4 8 6 7 4 9
#  6 7 5 3 4 0 5 9 9
#  d a v i s _ n a t h a n
#  2 5 3 1 5 9 7 7 7
#  e d w a r d s c h u t z
#  s a g a r _ c a r l
#  3 3 1 8 3 7 9 3 1
#  a a r o n b o n g a r d
#  t y 9 5 1 6
#  f r e d
#  s c h u s t e r s t e v e
#  m o o d y _ s c h i e b e l
#  s o l o m a n _ r a m a c h a n d r a n
#  v i c t o r 6 3 0
#  y a n g _ t r e b i l
#  h o f f m a n _ z e l l e r
#  r i p k a _ t h o m a s
#  v a d e r   h a l
#  o t t o c h a m b e r s
#  t y l u l l o f f
#  2 6 3 9 3 5 9 0 5
#  c a r l v a i l
#  h a n k t i s l e r
#  u d d i n 1 5 1 0
#  m c c o r m a c k   c a r l
#  v a d e r
#  n e l s o n m a r k
#  a d a m v a n   z a n d t
#  z i e g l e r   d a n
#  u f l a n
#  s a w y e r   f r a n k
#  d a n 6 8 5 8
#  s t a h l
#  t i m i r w i n
#  d a v i s 9 1 3 4
#  b e n u f l a n
#  d a v i d z i e g l e r
#  c a r l 1 9 5 9
#  a l e x k e l l e r
#  o s t r a n d e r j o e
#  4 6 9 3 2 2 1 1 6
#  m o n t e 7 2 0 7
#  l a w i c k i
#  f r e d t i e r n a n
#  f i e t z e r
#  b e n q u i n n
#  m a t t h e w 8 5 9 4
#  h a l   w e i s s
#  s w e e n e y   o t t o
#  f l e t c h e r _ m o n t e
#  a d a m k a l l e g
#  w o o t h o m a s
#  t h o m a s d a v i d s o n
#  m o o r e 3 4 9 0
#  w a l t e r
#  v e n t o t l a   a l e x
#  d i n k i n s
#  9 5 0 0 9 9 3 1 9
#  r o g e r   m y e r s
#  t i m   t r u s e l a
#  s a w y e r   a d a m
#  b e n   j a g t a p
#  c a r l m i l l s
#  m a r k b o y d
#  j o h n y o c u m
#  8 8 7 9 3 4 5 4 0
#  o r t i z j a c k
#  t i e r n a n 4 4 5 6
#  r o b e r t s _ m y e r s
#  s o l o m a n 8 3 7 0
#  a l e x 3 7 1 6
#  t i m
#  t h o m p s o n 8 5
#  r e y e s   j a c k
#  r e s n i c k
#  d i n k i n s r o g e r
#  m i l l s 9 6 3 4
#  8 2 1 4 6 4 7 4 7
#  v a l e n t e _ h y d i n g e r
#  s c h i e b e l 1 4 6 7
#  l a r r y s c h i e b e l
#  a d a m o s t r a n d e r
#  j a g t a p   f r e d
#  e d w a r d   h a w o r t h
#  m a t t h e w c a t a l d i
#  r e s n i c k _ m o o r e
#  z e l l e r
#  t r e b i l   g e o r g e
#  d u f f m a n
#  o t t o o r t i z
#  d a v i d   r i c e
#  d e l o r e n z o
#  m i l l e r _ k e l l e r
#  i l l i n g s w o r t h
#  n e l s o n
#  r o g e r s _ j o h n
#  f r e d w a g n e r
#  t y r e s n i c k
#  h a l   y a n g
#  t i e r n a n 6 9 5 0
#  s c h u s t e r   j o h n
#  m i l l s
#  c a s a l   h a n k
#  r o g e r   v a n   z a n d t
#  s t e v e v a d e r
#  h a n k u p s o n
#  1 8 4 5 3 6 3 6 6
#  i r w i n _ y a n g
#  n a p i e r   a a r o n
#  e d w a r d   s c h i c k o w s k i
#  f l e t c h e r   a l e x
#  c h a m b e r s   m o n t e
#  r o g e r s _ l a w i c k i
#  t a p i a _ u p s o n
#  u d d i n _ y o c u m
#  b o n g a r d r o g e r
#  v i c t o r
#  t y   s c h w a g e r
#  p a u l t i e r n a n
#  r o g e r 8 3 6
#  p e t t i g r e w   v i c t o r
#  s t e v e   i n g r a m
#  j o h n s e n 4 8 6 3
#  s o l o m a n   r o g e r
#  3 4 6 5 8 7 1 0
#  c a n n o n   j o e
#  2 8 4 8 5 7 1 4 6
#  8 9 0 2 8 0 3 1 6
#  k a l l e g   j o e
#  w e i n s t e i n   r o g e r
#  a l e x s c h m i t t
#  d a n   u d d i n
#  s t e v e   s t a h l
#  m a t t h e w f r i c k
#  2 3 7 3 3 6 9 8 9
#  l a r r y 6 0 1 6
#  o t t o 5 4 8 9
#  b o n g a r d _ t y
#  1 6 9 1 0 2 6 7 7
#  u p s o n   h a l
#  h a l
#  l e p a g e   a a r o n
#  s o n d e r l i n g _ m a r k
#  4 3 0 5 8 1 7 7 8
#  w a l t e r k a s s i n g
#  v i c t o r c e l e d o n
#  h e s c h   j o h n
#  k a s s i n g
#  d u f f m a n 6 0 0 5
#  f r a n k   v e n t o t l a
#  u d d i n o t t o
#  7 0 3 9 7 9 4 8 1
#  p a u l   n u g e n t
#  n u g e n t
#  a l e x
#  a a r o n s w e e n e y
#  k n u t s o n _ c e l e d o n
#  t y d o r a n
#  m i l l e r h a l
#  a d a m n u t t l e
#  a s h w o o n 8 6 0 9
#  v i c t o r m i l l e r
#  m c g i n n i s _ r e a r d o n
#  r a m a c h a n d r a n   m a r k
#  m o n t e s h a f f e r
#  m o n t e
#  p e t t i g r e w 9 7 5 0
#  y o c u m _ d a n
#  y o c u m   v i c t o r
#  d a r n e l l 8 4 8 3
#  z e l l e r   m a t t h e w
#  p e t t i g r e w l a r r y
#  y o c u m 8 1 4 6
#  b e n 5 0 3 9
#  m c g i n n i s   d a n
#  r o g e r   v o g a l
#  a d a m t i s l e r
#  m a t t h e w 3 4 2 0
#  j o h n 8 7 7 0
#  h e s c h _ z e l l e r
#  c h r i s t e n s e n _ b e n
#  w a l t e r   s o u l i s
#  b e n 8 6 7 1
#  f r a n k j a g t a p
#  p e t e r n u t t l e
#  v i c t o r 8 8 4 7
#  f e r r y   p a u l
#  6 9 0 3 7 7 0 3 4
#  l e p a g e r o g e r
#  j o h n   z e a s e r
#  v a l e n t e   j a c k
#  4 7 0 9 0 0 6
#  d e i t z   m o n t e
#  f i e t z e r   f r a n k
#  k a s k e l 5 2 8 4
#  d a v i d s o n   m o n t e
#  c a t a l d i _ i n g r a m
#  h a n k t i e r n a n
#  r i p k a 2 4 7 4
#  c a t a l d i _ m a t t h e w
#  l e w i s _ l u l l o f f
#  m a t t h e w m c c o r d
#  t u r c o 8 4 7 6
#  s t e v e 6 9 6 7
#  o r t i z   l a r r y
#  i r w i n c a r l
#  w a k e f i e l d j o e
#  n a t h a n s a g a r
#  h y d i n g e r _ l a r r y
#  f r a n k   y a t e s
#  f r e d
#  s c h u s t e r 5 8 6 8
#  r o g e r s c h w a g e r
#  1 6 3 6 2 2 4 2 6
#  b a x s t e r c a r l
#  y a n g   h a l
#  a i k i n
#  o r t i z   d a v i d
#  t i s l e r _ r e y e s
#  s t a h l   t h o m a s
#  a a r o n   t r u s e l a
#  5 7 3 1 6 8 8 6 8
#  m o n t e 1 0 2 1
#  p e t e r m c c o r d
#  q u i z o z
#  v a i l _ s o u k u p
#  t h o m a s s o n d e r l i n g
#  f r a n k a i k i n
#  a a r o n i l l i n g s w o r t h
#  8 5 9 4 9 1 3 3 7
#  p a u l   e a s t m a n
#  w a l t e r t i s l e r
#  f e r r o _ c a s w e l l
#  g e o r g e
#  t i m o r w i g
#  j o n e s
#  h o f f m a n   r o g e r
#  a s h w o o n
#  m a t t h e w   t r u s e l a
#  l a r r y 2 2 0 7
#  r i c e _ s o n d e r l i n g
#  n u t t l e b e n
#  d e w a l t _ m a r t i n
#  i k e k a s s i n g
#  2 4 0 0 4 4 2 8 9
#  o t t o
#  f e r r o   e d w a r d
#  h a n k a n d e r s o n
#  d e i t z   r o g e r
#  t u r c o _ i k e
#  d a n   d e i t z
#  o r w i g _ s w e e n e y
#  b e n c a s w e l l
#  c h a m b e r s   v i c t o r
#  s w e e n e y _ d a v i d
#  5 7 9 0 8 1 9 5 9
#  m o o r e   f r e d
#  t h o m a s
#  d a r n e l l   o t t o
#  o r w i g
#  h a w o r t h   j o h n
#  n a t h a n k a l l e g
#  h a l
#  y o c u m
#  r o b e r t s a l e x
#  a l e x 9 8 3 5
#  r o b e r t s   h a n k
#  n a t h a n r i p k a
#  s o n d e r l i n g
#  m a t t h e w   d u f f m a n
#  m o n t e 2 0 9 8
#  v i c t o r   t i e r n a n
#  c a t a l d i _ j o h n
#  8 2 2 1 4 0 5 6 9
#  j o e
#  m a t t h e w
#  w a l t e r
#  b a x s t e r _ z e a s e r
#  s c h i c k o w s k i   h a l
#  m o o d y   a l e x
#  y o c u m _ v e n t o t l a
#  v a d e r _ s w e e n e y
#  s c h u t z
#  o r w i g _ m i l l s
#  r o g e r 7 7 8 1
#  d u g a n _ t h o m a s
#  l u l l o f f
#  v a d e r
#  o t t o
#  s a w y e r _ j o h n s o n
#  g e o r g e
#  a n d e r s o n   j o h n
#  h y d i n g e r _ a a r o n
#  m o n t e
#  s e v e r s o n _ a a r o n
#  j a c k   f l e t c h e r
#  j u r g e n s o n p a u l
#  4 3 8 8 6 1 4 4 3
#  a a r o n
#  f l e t c h e r _ t h o m p s o n
#  w e i s s 2 3 3 4
#  e a s t m a n   t y
#  d o r a n
#  s w e e n e y _ n a t h a n
#  v o g a l 9 4 1 3
#  c e l e d o n _ b a u e r
#  v a d e r   v i c t o r
#  8 7 3 1 6 6 0 6 7
#  b e n   b o n g a r d
#  c a r l   w e i s s
#  4 2 1 9 3 1 3 2 0
#  c a t a l d i _ h a w o r t h
#  v o g a l   c a r l
#  2 9 0 2 7 3 7 4 6
#  t y b a u e r
#  l a r r y m y e r s
#  s o l o m a n   j a c k
#  r i c e _ m a r k
#  o r y m o n t e
#  m c g i n n i s   t i m
#  n a t h a n h a n c o c k
#  l a w l e s s   f r e d
#  p a u l k a s s i n g
#  f r e d r o o t
#  h e s c h   t y
#  n a p i e r 3 0 1 1
#  n a p i e r _ o r t i z
#  t y n a p i e r
#  t y 3 9 4 7
#  b e n
#  r e s n i c k m o n t e
#  s a w y e r
#  k a s k e l   p e t e r
#  s c h w a g e r 9 3 6 5
#  a a r o n l e w i s
#  n e l s o n _ j a c k
#  u p s o n 1 3 9 0
#  8 7 1 7 8 1 1 4 3
#  2 6 9 0 6 2 0 5 3
#  v i c t o r r e a r d o n
#  s o l o m a n
#  a a r o n s a g a r
#  a l e x
#  v a n   z a n d t 2 3 0 0
#  i k e 5 3 4 0
#  1 2 0 9 8 7 4 1 3
#  z i e g l e r
#  v a n   z a n d t
#  t i s l e r   m o n t e
#  v a n   z a n d t 8 5 1 9
#  v i c t o r q u i n n
#  l u l l o f f h a l
#  a a r o n e b n e r
#  f r e d   m o o r e
#  a d a m 3 6 0 5
#  t h o m p s o n
#  s t e v e w a g l e
#  m o n t e d e i t z
#  v a n d e r p o e l   a d a m
#  o r w i g _ j o h n
#  r o g e r
#  e d w a r d d e i t z
#  2 7 3 5 5 4 4 2 5
#  e d w a r d   d a r n e l l
#  m a r k n a p i e r
#  p a u l 6 3 5
#  u p s o n   p e t e r
#  j o h n   s t a h l
#  d u f f m a n   a a r o n
#  j e n s o n
#  r o g e r m c g i n n i s
#  s o u k u p
#  s o l o m a n
#  8 7 7 6 9 2 7 0 1
#  t a n d y a a r o n
#  i n g r a m t h o m a s
#  a a r o n 8 1 2 9
#  v a n d e r p o e l j o e
#  f r e d m i l l s
#  h a l j a g t a p
#  l a r r y   h a n c o c k
#  s o l o m a n _ e a s t m a n
#  m o n t e l e w i s
#  6 3 1 3 3 8 4 2 5
#  p e t e r   m c c o r d
#  h y l a n
#  r o g e r
#  p a i s e r
#  s c h i c k o w s k i   s t e v e
#  t y
#  r o b e r t s
#  9 5 8 6 4 2 4 3 8
#  b o y d 3 8 5 3
#  s o l o m a n _ n a t h a n
#  9 2 1 0 1 3 4 6
#  c h a m b e r s   m a r k
#  n u t t l e e d w a r d
#  a d a m r i c e
#  f r e d 9 3 7
#  b e n
#  l e p a g e m a r k
#  d a n
#  w a l t e r t u r c o
#  e b n e r _ f r e d
#  d a n w a g n e r
#  j o n e s 2 0 6
#  s t e v e   r o o t
#  r o g e r   f l e t c h e r
#  c a s a l   d a v i d
#  a d a m z i e g l e r
#  2 7 5 0 5 6 4 9 3
#  p e t e r l e w i s
#  j a c k
#  g e o r g e 3 7 8 8
#  s e v e r s o n p a u l
#  z e l l e r   r o g e r
#  o t t o s c h m i t t
#  f i e t z e r _ c a s t
#  t i e r n a n   j a c k
#  s c h u t z _ k n u t s o n
#  m a t t h e w 2 3 9 5
#  h a l   s e v e r s o n
#  r e y e s   p a u l
#  m c c o r d _ f e r r y
#  u d d i n 2 2 0 8
#  m o o d y 1 3 4 2
#  r o g e r 6 7 2 7
#  s c h l i c h t 6 7 0
#  s t e v e
#  s a w y e r
#  s o u l i s 2 8 6 3
#  y a t e s   s t e v e
#  s o n d e r l i n g 4 2 5 7
#  u p s o n _ p a u l
#  t i m t r e b i l
#  1 0 4 0 3 6 3 0 7
#  f r a n k u p s o n
#  f i e t z e r a l e x
#  s o l o m a n j o h n
#  p e t e r 6 5 6 4
#  j o h n s e n 2 1 9 9
#  u f l a n   f r a n k
#  l e p a g e _ e d w a r d
#  d u g e l m a n 8 8 7 2
#  c a r l v a n d e r p o e l
#  v a n d e r p o e l _ h y d i n g e r
#  r i p k a 2 7 8 9
#  c h a m b e r s   a a r o n
#  n a t h a n 2 4 5 4
#  l a r r y 1 5 9 6
#  m o o r e t y
#  r o g e r   f i e t z e r
#  s o u l i s p e t e r
#  v i c t o r s c h m i t t
#  t y 3 5 0 3
#  l e p a g e _ o s t r a n d e r
#  v a n d e r p o e l _ d a n
#  d a r n e l l t y
#  k a l l e g _ d a v i d
#  s t e v e
#  l u l l o f f   m a t t h e w
#  c h a m b e r s p a u l
#  a n d e r s o n 8 4 5
#  q u i z o z _ u p s o n
#  b e n c a s a l
#  v a d e r _ j o h n
#  m a r k   l e p a g e
#  l e p a g e 6 6 9 8
#  z e l l e r _ z i e g l e r
#  w a l t e r s c h w a g e r
#  c h r i s t e n s e n t y
#  s e v e r s o n _ w o o
#  v a i l j o e
#  t i e r n a n   f r a n k
#  d e w a l t _ a d a m
#  r o g e r t r e b i l
#  z i e g l e r 8 9 2 8
#  d u f f m a n   b e n
#  w a k e f i e l d _ e d w a r d
#  d u g e l m a n _ v a n   z a n d t
#  n u g e n t 1 3 3 1
#  f r i c k   o t t o
#  c e l e d o n _ s e v e r s o n
#  t y   t i e r n a n
#  s c h m i t t
#  a a r o n w a g l e
#  w o o
#  t i m 9 5 4 2
#  j o h n 5 6 9 4
#  s a g a r _ n a t h a n
#  l a r r y   d i n k i n s
#  s e v e r s o n   s t e v e
#  f r e d t u r c o
#  v i c t o r i n g r a m
#  e d w a r d
#  t i s l e r   m a t t h e w
#  r e y e s   r o g e r
#  r e a m e r _ t i m
#  s c h l i c h t   c a r l
#  s t e v e 3 1 3 1
#  w a g n e r 9 1 3 6
#  d a v i s _ b o w e r s
#  e d w a r d 9 0 7 9
#  2 8 3 1 4 1 3 3 0
#  t y d u f f m a n
#  w a l t e r h y d i n g e r
#  b e n 9 6 3 5
#  v a n d e r p o e l   m a r k
#  d e l o r e n z o   j a c k
#  c h a p m a n   r o g e r
#  n a t h a n   w o o
#  v i c t o r v a d e r
#  b a t e m a n 1 5 2 2
#  b e n   i r w i n
#  f r e d h a w o r t h
#  e a s t m a n _ l a r r y
#  s w e e n e y _ a l e x
#  h y d i n g e r _ o t t o
#  p e t e r 2 6 0 0
#  e a s t m a n _ a d a m
#  t h o m a s
#  h a l
#  p a u l r e s n i c k
#  6 8 2 8 0 4 9 2 2
#  z i e g l e r   a l e x
#  m a k i   f r a n k
#  m y e r s p e t e r
#  f r e d 6 7
#  e d w a r d h o f f m a n
#  n u t t l e   m o n t e
#  t h o m p s o n _ o r w i g
#  i k e   s t a h l
#  m a r k h o f f m a n
#  6 6 9 2 1 4 2 8 2
#  h a n k
#  p e t t i g r e w _ b a u e r
#  n u t t l e _ u p s o n
#  v a d e r _ t y
#  d a n z i e g l e r
#  n u g e n t _ u d d i n
#  a l e x   m c c o r m a c k
#  l a r r y
#  a a r o n 7 3 5
#  d e i t z d a n
#  a l e x h e s c h
#  d i n k i n s c a r l
#  a a r o n s c h w a g e r
#  e d w a r d
#  o r y   t y
#  d u g e l m a n _ r o g e r
#  4 3 7 2 0 8 5 4
#  l a r r y u l r i c h
#  t i e r n a n o t t o
#  c h r i s t e n s e n   b e n
#  2 2 0 9 2 3 6 3 2
#  s t a h l _ l a r r y
#  v a d e r _ l a r r y
#  l e p a g e
#  w o o f r a n k
#  4 1 3 3 5 2 7 8 1
#  w a l t e r s c h u t z
#  i k e
#  t i s l e r j o h n
#  e b n e r _ c h a p m a n
#  j u r g e n s o n   m a r k
#  4 0 0 5 3 0 2 2
#  n a t h a n h y l a n
#  c a r l 1 2 6 6
#  o r t i z
#  j o h n s e n 1 4 0 0
#  i r w i n _ o t t o
#  i k e c h a p m a n
#  w a l t e r
#  n a t h a n   z e l l e r
#  j o e u d d i n
#  l a w i c k i
#  c a s a l 9 1 5 6
#  r e s n i c k 2 7 5 4
#  a s h w o o n _ h a n k
#  j a c k 3 7 4 0
#  h a l   c a s a l
#  j u r g e n s o n _ d a n
#  3 9 3 5 4 3 3 9 8
#  s t e v e 5 7 6 9
#  d u f f m a n _ v a n d e r p o e l
#  r a m a c h a n d r a n 1 7 1 2
#  d u g e l m a n   a d a m
#  7 3 5 3 5 4 7 2 2
#  m o n t e s c h i e b e l
#  l a r r y   m i l l e r
#  l e p a g e   p e t e r
#  d u f f m a n e d w a r d
#  t i m   r o b e r t s
#  s c h i c k o w s k i   m a t t h e w
#  s t e v e
#  d u f f m a n _ w e i s s
#  r o g e r s t y
#  p a u l c h a p m a n
#  a d a m   d e l o r e n z o
#  b o n g a r d b e n
#  k n u t s o n   w a l t e r
#  o r y _ j o e
#  c h a m b e r s   w a l t e r
#  c a n n o n _ f e r r o
#  r i c e _ s o u l i s
#  5 7 9 0 9 7 7 3 7
#  c h a m b e r s _ r o b e r t s
#  p e t t i g r e w f r e d
#  v i c t o r i l l i n g s w o r t h
#  w a g n e r c a r l
#  i l l i n g s w o r t h   r o g e r
#  f r e d
#  t a p i a j o h n
#  c h r i s t e n s e n
#  v a i l
#  n a t h a n
#  t a n d y
#  v i c t o r j o n e s
#  r e s n i c k   d a v i d
#  r o g e r
#  r e s n i c k   t h o m a s
#  s o u k u p _ t i m
#  h a n k
#  v i c t o r f l e t c h e r
#  s c h w a g e r _ p a k
#  w e i n s t e i n t i m
#  f r e d 2 4 1 4
#  h e s c h 1 6 4 8
#  w e i s s _ w a l t e r
#  o t t o r e a m e r
#  c a r l
#  f i e t z e r _ k a s k e l
#  t i m b a u e r
#  i k e   r e y e s
#  m a t t h e w
#  r e a r d o n
#  m c c o r m a c k 7 9 4 6
#  m a t t h e w 6 9 9 3
#  n e l s o n   m a t t h e w
#  p e t e r   m c c o r m a c k
#  d e l o r e n z o   l a r r y
#  m c g i n n i s   w a l t e r
#  e d w a r d 3 6 3 9
#  m a r k 2 1 9 2
#  d a n
#  n u t t l e t y
#  v i c t o r t i s l e r
#  t i s l e r _ c a n n o n
#  o t t o   j u r g e n s o n
#  j a c k s o l b e r g
#  n a t h a n   v a n d e r p o e l
#  f l e t c h e r _ d u f f m a n
#  d u g a n _ o r t i z
#  a n d e r s o n _ d e w a l t
#  a d a m p a k
#  p e t e r   n o r q u i s t
#  y a n g
#  a l e x 7 6 2 7
#  b e n
#  f e r r y   w a l t e r
#  w e i s s 9 4 0 1
#  h a w o r t h _ s t e v e
#  u l r i c h 9 3 3 1
#  b a x s t e r   m a r k
#  d u g e l m a n 2 7 2 7
#  y a t e s _ h a l
#  o t t o 1 5 4 3
#  b a t e m a n _ j o e
#  l a r r y h o f f m a n
#  c e l e d o n m a t t h e w
#  v i c t o r r o g e r s
#  a s h w o o n _ b e n
#  v a n   z a n d t _ d e i t z
#  7 1 1 9 7 8 8 5 5
#  d e l o r e n z o
#  z e l l e r _ j o h n
#  o l s o n
#  a a r o n m i l l e r
#  b e n s o u k u p
#  s w e e n e y t i m
#  j o e
#  d o r a n
#  o t t o
#  f r a n k c h r i s t e n s e n
#  5 2 4 5 0 4 2 6 2
#  t i m 3 7 9 3
#  o t t o 8 1 5
#  s w e e n e y   c a r l
#  k n u t s o n _ t r e b i l
#  h a n k   n u t t l e
#  k a l l e g   t i m
#  i k e c a s t
#  j a c k   w e i n s t e i n
#  m y e r s _ r a m a c h a n d r a n
#  v i c t o r
#  h a n c o c k c a r l
#  s c h l i c h t   d a n
#  t i s l e r 3 2 9 7
#  s t e v e 6 5 0 2
#  f r a n k 5 5 0 6
#  s c h w a g e r _ j o e
#  d u g e l m a n   j a c k
#  w e i s s 5 2 6 1
#  d a n t r u s e l a
#  l e i s i n g e r _ w a l t e r
#  r o g e r 4 9 6 5
#  m c c o r m a c k _ i k e
#  j a c k o r t i z
#  w a l t e r
#  f e r r o _ p e t e r
#  i k e m y e r s
#  s c h m i t t
#  y a t e s   t h o m a s
#  s c h u t z i k e
#  u p s o n
#  s c h l i c h t   m o n t e
#  u p s o n
#  5 2 5 0 7 2 4 0 0
#  j u r g e n s o n _ t r u s e l a
#  g e o r g e t u r c o
#  h a n k 5 8 9 1
#  w e i s s   h a n k
#  j e n s o n 9 6 4 2
#  t h o m a s c a s w e l l
#  t h o m a s k a l l e g
#  b o w e r s   s t e v e
#  v i c t o r r e s n i c k
#  w a l t e r 8 0 8 2
#  s e l l o n _ r o g e r
#  p e t e r
#  v i c t o r 2 7 0 0
#  d e i t z   e d w a r d
#  3 8 4 6 0 0 1 4
#  h e s c h _ m i l l s
#  f r a n k w o o
#  v a n   z a n d t _ s o l o m a n
#  u l r i c h _ c a r l
#  a d a m
#  h o f f m a n
#  z e l l e r s t e v e
#  j o n e s t h o m a s
#  j a g t a p _ v i c t o r
#  r e y e s 3 3 2 5
#  s c h i c k o w s k i 7 1 9 0
#  i r w i n
#  m o o r e _ e d w a r d
#  t i s l e r _ f r e d
#  t h o m a s
#  a l e x c a t a l d i
#  t i m
#  h a n k u l r i c h
#  o t t o   r e a m e r
#  r o g e r c h a m b e r s
#  a l e x d a v i d s o n
#  p e t e r   m o o d y
#  b e n   w e i n s t e i n
#  d a v i d s o n _ j a c k
#  j a c k s e l l o n
#  c a t a l d i e d w a r d
#  s e l l o n   j a c k
#  7 4 8 5 2 2 7 6 6
#  v i c t o r s w e e n e y
#  n e l s o n   m a t t h e w
#  j o h n m o o d y
#  p e t e r   s a n d s t r o m
#  m o n t e l u l l o f f
#  a n d e r s o n h a l
#  n a p i e r _ h a n k
#  m o o d y g e o r g e
#  p e t e r 4 8 0 9
#  m a r k n a p i e r
#  d a r n e l l _ r o g e r
#  g e o r g e
#  t i m   w e i n s t e i n
#  p a k _ r o g e r
#  g e o r g e c a s a l
#  t r u s e l a   j a c k
#  t h o m a s v a n   z a n d t
#  f r e d   m a r t i n
#  a l e x
#  d a n   v e n t o t l a
#  d e w a l t _ j o e
#  c e l e d o n _ h e s c h
#  t y 8 6 8 4
#  n u t t l e _ y a n g
#  h a l   r i c e
#  8 2 1 6 6 3 8 2 4
#  m c c o r d   f r e d
#  o r w i g
#  8 5 7 0 7 1 9 2 6
#  t u r c o l a r r y
#  m c g i n n i s _ a a r o n
#  j o h n p e t t i g r e w
#  r o o t   e d w a r d
#  h a l   y o c u m
#  m o n t e s c h u s t e r
#  f i e t z e r _ m a r k
#  2 7 1 7 9 4 9 9 7
#  h a n c o c k
#  w a g l e _ d o r a n
#  5 5 8 7 9 1 2 0 2
#  w o o   a a r o n
#  q u i n n 1 0 9 7
#  s a w y e r
#  t r e b i l 5 3 3 9
#  n o r q u i s t   m a r k
#  o r y 7 6 6 4
#  o l s o n j o h n
#  o r w i g f r a n k
#  a l e x f r i c k
#  k n u t s o n _ m a t t h e w
#  a i k i n 7 9 9 6
#  d e w a l t 6 7 4
#  v e n t o t l a _ h a w o r t h
#  i k e
#  y a t e s   h a l
#  d a n 9 8 8 1
#  r e s n i c k _ j o h n
#  r o g e r   d e i t z
#  p a k   m a t t h e w
#  e d w a r d
#  m a r k m o o r e
#  s c h i c k o w s k i   r o g e r
#  l a r r y s a n d s t r o m
#  n a t h a n
#  f r e d o l s o n
#  n a t h a n   r o g e r s
#  n e l s o n   p e t e r
#  a d a m e a s t m a n
#  s o l b e r g
#  c a r l   m c g i n n i s
#  b e n w o o
#  t r u s s e l _ m o o r e
#  v a d e r _ t h o m p s o n
#  d a v i d a s h w o o n
#  s a w y e r   s t e v e
#  r o g e r b a t e m a n
#  d i n k i n s _ w e i n s t e i n
#  r e s n i c k   e d w a r d
#  r o g e r c a n n o n
#  e b n e r _ w a l t e r
#  a a r o n
#  h a l d u f f m a n
#  c e l e d o n _ o s t r a n d e r
#  r o g e r h o f f m a n
#  v i c t o r 2 9 4 9
#  m a t t h e w   s c h w a g e r
#  d a n 9 8 6 2
#  l a w i c k i   c a r l
#  t i s l e r t i m
#  v i c t o r 3 3 3 4
#  a l e x
#  p e t e r   t i s l e r
#  t r e b i l
#  7 8 6 3 3 1 2 6 4
#  t y j o h n s o n
#  v a l e n t e 5 1 2 0
#  j o e s a w y e r
#  z e l l e r   n a t h a n
#  1 8 7 6 3 0 4 4 3
#  9 2 6 6 0 9 6 3 5
#  j o h n
#  m y e r s 6 4 7 5
#  o r t i z 8 4 0 0
#  s a n d s t r o m g e o r g e
#  h y l a n _ t a n d y
#  a d a m m c c o r d
#  j a c k j e n s o n
#  m a t t h e w 3 8 6 2
#  d a v i d 8 0 8 4
#  j o h n m i l l s
#  h a l j o n e s
#  l a w l e s s   t y
#  w a l t e r
#  t r u s e l a   p e t e r
#  t r e b i l   a l e x
#  s c h i c k o w s k i   a l e x
#  e d w a r d 6 5 6 7
#  c a r l 3 8 0 3
#  a s h w o o n _ v a i l
#  u d d i n 2 1 4 1
#  s c h w a g e r   e d w a r d
#  c a t a l d i   r o g e r
#  6 5 2 7 6 8 9 1 1
#  l e p a g e   j o h n
#  r o g e r u p s o n
#  v a i l _ p e t e r
#  j o h n s o n 9 3 9 8
#  a l e x 7 3 8 5
#  l a r r y k a s s i n g
#  m c c o r m a c k   t h o m a s
#  6 1 0 6 0 1 9 0 0
#  h a l r o b e r t s
#  b o w e r s   t h o m a s
#  t i m w e i n s t e i n
#  w a g n e r _ f r a n k
#  b e n l i n d e
#  b a x s t e r a a r o n
#  r o g e r s
#  l e w i s   p a u l
#  m i l l s   c a r l
#  r o o t 9 7 4 4
#  k a s k e l   p a u l
#  j a c k
#  y a n g a a r o n
#  j o n e s _ t h o m a s
#  v o g a l _ j a c k
#  d i n k i n s   v i c t o r
#  c a r l w a k e f i e l d
#  d a r n e l l _ s e v e r s o n
#  5 2 2 1 7 7 6 5 5
#  m a r k l e w i s
#  6 5 4 3 1 4 2 1 2
#  g e o r g e t a n d y
#  m y e r s a d a m
#  l a w i c k i 5 4 4 8
#  b a t e m a n
#  a l e x s e v e r s o n
#  h a n k   c a t a l d i
#  n a t h a n 9 4 7 3
#  r o o t c a r l
#  d u g e l m a n _ v e n t o t l a
#  a a r o n b a u e r
#  i k e m a k i
#  m a t t h e w
#  s c h u t z   h a l
#  r o g e r   i l l i n g s w o r t h
#  j o h n 5 3 8 0
#  j o h n s e v e r s o n
#  f r a n k   u l r i c h
#  f r a n k   w a g n e r
#  v a n   z a n d t   w a l t e r
#  v a n   z a n d t r o g e r
#  9 1 9 9 7 1 7 8 6
#  n a t h a n d u g a n
#  w a g n e r   c a r l
#  g e o r g e 5 6 5 1
#  m a r k 7 0 7 1
#  c a t a l d i r o g e r
#  c a r l u l r i c h
#  i l l i n g s w o r t h n a t h a n
#  m o o r e   a a r o n
#  m a k i _ a l e x
#  c a r l t r u s s e l
#  d a v i d s o n   a d a m
#  v a i l 2 9 5 4
#  s o l b e r g _ o r t i z
#  3 3 7 3 4 1 2 4 8
#  b a x s t e r   a l e x
#  c a s t
#  j a c k m c c o r m a c k
#  s o u k u p _ n u g e n t
#  f r a n k
#  s e v e r s o n 3 8 5 9
#  m y e r s _ a a r o n
#  m a r k r o g e r s
#  j a c k d u f f m a n
#  t y 2 5 3 0
#  r i c e 5 2 5
#  m a t t h e w p a i s e r
#  s w e e n e y
#  k a s s i n g a d a m
#  n u t t l e 5 1 4 6
#  j o e w a g n e r
#  j u r g e n s o n   r o g e r
#  h a n k 9 6 5 0
#  b a t e m a n   s t e v e
#  t h o m a s
#  s t e v e s o u k u p
#  2 3 6 8 9 3 3 7 3
#  s c h u s t e r h a n k
#  p a k
#  t i m a i k i n
#  s t a h l w a l t e r
#  f r a n k k a s k e l
#  b a x s t e r _ f e r r y
#  v o g a l   l a r r y
#  d a v i d r o o t
#  p a u l
#  t a n d y
#  s t e v e
#  8 9 2 9 1 9 2 4
#  s e l l o n 9 6 4 3
#  n o r q u i s t 5 1 5 1
#  f r e d t a p i a
#  h a n c o c k   b e n
#  f e r r y   r o g e r
#  c h a p m a n 6 4 0 5
#  c a r l 1 7 2
#  d a v i d 2 5 6 3
#  k n u t s o n _ m o n t e
#  t y w a k e f i e l d
#  z e l l e r d a n
#  t a p i a m o n t e
#  y a n g   h a l
#  m a k i e d w a r d
#  v e n t o t l a e d w a r d
#  s t a h l
#  j o e   p e t t i g r e w
#  j o h n s o n
#  r o g e r 4 4 9 4
#  m i l l e r _ d a n
#  t u r c o v i c t o r
#  v a n d e r p o e l _ g e o r g e
#  g e o r g e   z i e g l e r
#  s w e e n e y   r o g e r
#  m o n t e v a n d e r p o e l
#  r e y e s _ h a n k
#  s e l l o n _ r e y e s
#  l a r r y
#  m c c o r m a c k   d a v i d
#  z e l l e r _ m o o d y
#  d o r a n
#  a d a m a s h w o o n
#  r e a r d o n 5 9 7 7
#  d e w a l t _ h o f f m a n
#  r o b e r t s _ s w e e n e y
#  l a w i c k i 2 8 0 0
#  a l e x   s e l l o n
#  p a u l n o r q u i s t
#  d a n
#  f r e d 3 1 3 1
#  s t e v e 3 2 2 9
#  8 9 9 7 8 2 5 7 7
#  l i n d e _ t i m
#  7 6 5 3 6 7 1 2 1
#  h a w o r t h j o h n
#  u f l a n _ j o e
#  u p s o n
#  7 1 3 4 3 2 8 5 1
#  a n d e r s o n _ y a t e s
#  k a s s i n g p e t e r
#  7 4 5 5 8 5 1 0 4
#  r o g e r o l s o n
#  a d a m   m o o r e
#  m o n t e l u l l o f f
#  p e t e r
#  o r t i z _ s t e v e
#  v i c t o r w e i s s
#  n u t t l e j o e
#  t h o m a s s o u l i s
#  t u r c o   j o h n
#  t y b o y d
#  j o h n r i c e
#  v a l e n t e _ u l r i c h
#  f i e t z e r
#  h a l r o g e r s
#  h a w o r t h
#  c a r l 7 3 3 8
#  m o o d y 7 1 9 8
#  f i e t z e r   g e o r g e
#  r e s n i c k _ t i s l e r
#  b e n   e b n e r
#  v i c t o r
#  9 1 2 0 7 1 4 2
#  s w e e n e y e d w a r d
#  n o r q u i s t   j a c k
#  m c c o r d _ p a i s e r
#  t i m 6 0 3 8
#  z i e g l e r 5 4 0 6
#  f r a n k p a i s e r
#  h y l a n   j o e
#  t r u s e l a 3 8 5 4
#  j a g t a p _ k e l l e r
#  f e r r o   o t t o
#  t u r c o d a n
#  r i p k a j o h n
#  i k e   k a l l e g
#  3 9 3 5 9 2 7 8 8
#  q u i n n _ r o g e r
#  m i l l s   p e t e r
#  s e v e r s o n _ d e l o r e n z o
#  u f l a n
#  r e y e s _ p a u l
#  w o o _ q u i z o z
#  q u i z o z   e d w a r d
#  t i m i l l i n g s w o r t h
#  o t t o 1 4 7
#  s t e v e   v a n   z a n d t
#  s a g a r _ w e i n s t e i n
#  f r a n k m a r t i n
#  s c h u s t e r _ j o e
#  r e y e s 3 2 3 6
#  d a v i s
#  c a r l j o n e s
#  b o y d _ c a r l
#  k a s k e l
#  t h o m p s o n   a l e x
#  r o b e r t s _ b a x s t e r
#  i r w i n _ i k e
#  r o g e r d u f f m a n
#  z e a s e r _ c a s a l
#  l a w l e s s   t h o m a s
#  c a r l   c e l e d o n
#  m a r k s o n d e r l i n g
#  f r a n k   u l r i c h
#  6 2 2 5 7 5 1 7 6
#  t i s l e r
#  5 5 9 5 7 3 6 0 1
#  d a v i s   p e t e r
#  z e a s e r   m a r k
#  w a l t e r
#  m a t t h e w
#  i k e c a s a l
#  q u i n n _ t h o m a s
#  h a l   l e i s i n g e r
#  p a k
#  d a v i d
#  e d w a r d
#  l a w l e s s 5 4 5 6
#  y a t e s 9 6 1 0
#  5 8 6 4 3 3 4 9 3
#  d a n s o n d e r l i n g
#  c a r l s t a h l
#  b a u e r _ r e a m e r
#  l e p a g e 9 4 7 4
#  t h o m a s   w a g l e
#  s t e v e s h a f f e r
#  5 6 2 0 7 5 7 8 2
#  n o r q u i s t h a n k
#  s a n d s t r o m g e o r g e
#  e d w a r d m a k i
#  m a r k l e w i s
#  4 7 3 7 5 5 1 8 9
#  5 4 2 2 3 7 3 1 7
#  p e t e r d u f f m a n
#  u d d i n t y
#  d a v i d
#  h e s c h   i k e
#  r o b e r t s   m o n t e
#  r o g e r o s t r a n d e r
#  i k e r e a r d o n
#  f l e t c h e r 2 6 3 7
#  v a d e r m a r k
#  a l e x   v a n   z a n d t
#  d a n m c g i n n i s
#  d e l o r e n z o   o t t o
#  r o o t   a a r o n
#  d u g a n   n a t h a n
#  j o h n s e n 5 0 9 0
#  b a t e m a n
#  3 9 4 7 5 8 7 5 9
#  s w e e n e y
#  u p s o n _ l a w l e s s
#  f r a n k i l l i n g s w o r t h
#  j a g t a p _ s a w y e r
#  s c h u t z 5 9
#  l a r r y   u p s o n
#  f l e t c h e r   n a t h a n
#  y o c u m a l e x
#  s o l b e r g   v i c t o r
#  r o o t _ k a s k e l
#  c e l e d o n s t e v e
#  d a v i d
#  m a t t h e w   f l e t c h e r
#  j a c k s a n d s t r o m
#  h a n k l a w l e s s
#  b o w e r s _ s t e v e
#  v o g a l   a l e x
#  d e w a l t 7 1 2 4
#  s c h w a g e r _ r o o t
#  l a r r y 6 5 1 6
#  h a n k
#  c h a p m a n _ f r e d
#  j a c k q u i n n
#  d a r n e l l   p e t e r
#  l e w i s   e d w a r d
#  s c h i c k o w s k i 1 1 1 2
#  s w e e n e y
#  u d d i n   j o h n
#  r o g e r t r u s s e l
#  s o l o m a n
#  a d a m   n u g e n t
#  t h o m p s o n
#  u l r i c h 8 1 9 5
#  d o r a n i k e
#  t i e r n a n _ j o h n s o n
#  8 6 0 8 1 2 9 5 2
#  n e l s o n _ s e v e r s o n
#  m c c o r m a c k _ c a s w e l l
#  s o l b e r g   r o g e r
#  b a x s t e r   t i m
#  n a t h a n f l e t c h e r
#  h a n k
#  c e l e d o n _ o r y
#  t r u s e l a
#  p e t e r   c a t a l d i
#  t i m 9 7 1 1
#  f r a n k 8 6 8 8
#  s c h u s t e r f r a n k
#  d a v i d v a n   z a n d t
#  o t t o   v a l e n t e
#  j o h n s o n _ v i c t o r
#  k n u t s o n
#  d e l o r e n z o m a r k
#  c h a m b e r s 6 1 5 5
#  h y d i n g e r 6 9 6 7
#  t a n d y   b e n
#  s o n d e r l i n g   d a n
#  t h o m a s 9 5 4 7
#  u p s o n p a u l
#  d a v i d
#  m a r k   l a w i c k i
#  d a r n e l l _ j a c k
#  6 4 0 5 3 8 8 1 7
#  m o n t e
#  r o g e r   s a g a r
#  f r a n k w a g l e
#  j a c k
#  f r a n k
#  m y e r s   h a n k
#  6 1 2 5 7 7 6 3 1
#  d e i t z m a r k
#  s e l l o n _ t h o m a s
#  m a t t h e w d a v i s
#  d a v i d 4 7 0 4
#  g e o r g e   o r w i g
#  o r w i g _ a l e x
#  9 7 8 6 0 9 3 5 5
#  y o c u m t y
#  m i l l e r
#  g e o r g e   b a t e m a n
#  s a w y e r _ l a r r y
#  u l r i c h   r o g e r
#  1 5 0 7 7 5 9 8
#  t i m d u g e l m a n
#  f r a n k n u t t l e
#  a d a m n e l s o n
#  n u t t l e _ w a l t e r
#  k e l l e r _ m o n t e
#  n a t h a n   l u l l o f f
#  l i n d e   h a n k
#  a a r o n c a s t
#  f r e d m c c o r d
#  i l l i n g s w o r t h 4 8 8 5
#  m a r k s h a f f e r
#  v i c t o r
#  q u i n n 8 8 7 1
#  t h o m a s b o n g a r d
#  a l e x v a l e n t e
#  i l l i n g s w o r t h   b e n
#  a d a m   k a l l e g
#  h a n k n e l s o n
#  r o g e r
#  r e y e s t y
#  j o e l e p a g e
#  d a n d e w a l t
#  m c c o r d   h a l
#  t h o m a s
#  b e n   b o y d
#  w a g n e r   m o n t e
#  h a n c o c k s t e v e
#  b o y d
#  d e l o r e n z o 8 6 8 3
#  r e y e s
#  h e s c h   e d w a r d
#  t a p i a
#  r o g e r r a m a c h a n d r a n
#  f l e t c h e r   l a r r y
#  h e s c h   r o g e r
#  v a l e n t e
#  d e w a l t _ s c h l i c h t
#  j u r g e n s o n 4 9 6
#  j o h n
#  s o u k u p
#  j a c k   d e i t z
#  j o h n
#  t r u s s e l _ m a t t h e w
#  v i c t o r
#  l e i s i n g e r 9 1 2 4
#  u d d i n   m a t t h e w
#  r o g e r 1 0 8 6
#  t h o m a s b a t e m a n
#  b o n g a r d _ m o o r e
#  f l e t c h e r p e t e r
#  i r w i n 6 4 2 5
#  i r w i n h a l
#  w e i n s t e i n 7 3 7 9
#  7 5 3 7 6 0 7 5 7
#  h a n k t r u s s e l
#  o l s o n
#  n a t h a n 4 2 4
#  c a s a l
#  r o g e r l a w l e s s
#  j a c k h o f f m a n
#  a d a m 4 3 5 3
#  b e n   l e w i s
#  t i e r n a n 9 5 2 6
#  s w e e n e y 3 1 2 3
#  d e l o r e n z o   t h o m a s
#  w a g l e
#  5 2 7 8 8 1 8 0 5
#  8 7 2 8 3 4 7 2 4
#  l i n d e 4 4 3
#  h y d i n g e r 2 4 3 1
#  o r y   p a u l
#  f e r r o
#  p a u l   t a n d y
#  l e i s i n g e r 7 9 2 5
#  o t t o
#  s a w y e r d a n
#  u l r i c h
#  d e w a l t j o h n
#  d a v i d u d d i n
#  s c h u s t e r 4 6 6 5
#  w a l t e r
#  a i k i n
#  h a l t i s l e r
#  r o g e r   n u t t l e
#  f r a n k m c c o r d
#  7 9 0 0 6 8 4 0 4
#  f l e t c h e r   p e t e r
#  p a u l
#  n u g e n t 2 2 7 7
#  j o h n d u g e l m a n
#  m a r k w a g l e
#  f e r r y 9 4 1 9
#  j o e
#  s o n d e r l i n g _ d i n k i n s
#  m a t t h e w t r e b i l
#  r o g e r c h a p m a n
#  v a n d e r p o e l   r o g e r
#  j o e 2 4 7 5
#  p a i s e r _ m o o d y
#  p a i s e r
#  p e t e r   v e n t o t l a
#  t i e r n a n   i k e
#  5 2 4 1 6 7 3 4 2
#  h a l   n u g e n t
#  v a n d e r p o e l   m a t t h e w
#  p e t e r s a w y e r
#  e d w a r d 1 5 9 5
#  t h o m a s r o o t
#  7 2 0 0 5 4 8 3 8
#  8 3 5 5 5 5 7 3 0
#  m c c o r d 9 6 9
#  l a w i c k i   b e n
#  e d w a r d j e n s o n
#  d a r n e l l _ t y
#  h a n k 2 6 7 6
#  v i c t o r t u r c o
#  d u g a n
#  f r e d 6 9 4 6
#  f e r r o
#  o s t r a n d e r _ r o g e r
#  s t e v e w a g l e
#  c a r l   k e l l e r
#  h a l 7 7 1 4
#  9 2 1 2 9 5 5 0 8
#  h a n k 9 4 4
#  t u r c o _ d a v i d
#  b a x s t e r
#  s c h u t z _ t i e r n a n
#  b o y d _ e a s t m a n
#  t i s l e r m o n t e
#  f e r r y n a t h a n
#  a i k i n _ j o h n s e n
#  c a r l s c h u s t e r
#  a d a m f e r r o
#  h a w o r t h _ o s t r a n d e r
#  p e t e r o s t r a n d e r
#  m a t t h e w   s c h l i c h t
#  z e l l e r _ t y
#  f r e d 5 4 2
#  c h a p m a n _ r o g e r
#  s h a f f e r
#  n a p i e r _ t i m
#  r e s n i c k _ s o l o m a n
#  h y d i n g e r   v i c t o r
#  r e a r d o n n a t h a n
#  l a r r y 5 2 3 0
#  i r w i n f r a n k
#  t r e b i l r o g e r
#  7 7 8 8 0 5 8 0 8
#  b e n d u f f m a n
#  s t a h l _ p e t e r
#  z e a s e r _ l a w i c k i
#  t i s l e r
#  j o h n
#  d a v i d d a v i d s o n
#  j o e s c h m i t t
#  j o n e s 3 4 8 0
#  h a l   d a v i d s o n
#  d a n   s o l o m a n
#  t r u s e l a   j o e
#  p a k _ a a r o n
#  p e t t i g r e w _ w a l t e r
#  s o l b e r g _ p e t e r
#  o r y   i k e
#  o t t o r e a m e r
#  e b n e r 2 2 4 7
#  r o g e r l a w i c k i
#  a d a m 3 4 9 3
#  1 0 5 2 2 5 9 4 1
#  e d w a r d t i e r n a n
#  h a l
#  t y q u i n n
#  t h o m a s h a n c o c k
#  w a g l e   c a r l
#  q u i n n _ d a v i d
#  1 9 6 2 3 1 5 9
#  e b n e r   t h o m a s
#  c a s t 3 5 0 0
#  e d w a r d
#  s c h w a g e r 4 1 4 9
#  h a l   v o g a l
#  f r e d 6 0 9 7
#  u d d i n _ c e l e d o n
#  3 2 8 0 2 7 9 9 4
#  d o r a n   v i c t o r
#  p e t e r s o n d e r l i n g
#  a l e x l a w l e s s
#  f l e t c h e r 6 0 8 0
#  d a v i d 9 6 7 5
#  l e w i s   t h o m a s
#  h a l
#  s h a f f e r _ a d a m
#  o r y s t e v e
#  z e l l e r t y
#  r e s n i c k _ t y
#  t u r c o l a r r y
#  r o g e r 7 8 7 0
#  s o l b e r g   m o n t e
#  i k e o l s o n
#  t i m   v o g a l
#  d a v i d s o n _ j o e
#  1 1 3 9 9 2 5 5 3
#  w e i s s _ k e l l e r
#  r o b e r t s 5 2 6 1
#  d u g a n   l a r r y
#  t h o m p s o n h a n k
#  t r u s s e l   a d a m
#  s c h w a g e r
#  p a u l
#  j a c k f e r r o
#  i n g r a m _ s c h u t z
#  w a g n e r   l a r r y
#  t y s h a f f e r
#  t a p i a 2 8 7
#  f r e d 4 6 3 9
#  s t e v e i n g r a m
#  a l e x
#  m o o d y _ a l e x
#  p e t e r r i c e
#  d a v i d y a t e s
#  s e l l o n _ m a r k
#  d u g a n j a c k
#  g e o r g e 7 6 7 7
#  9 4 7 9 3 2 0 5 1
#  k a s s i n g m o n t e
#  r e y e s g e o r g e
#  e d w a r d   o r w i g
#  l a w l e s s _ s t e v e
#  s o u l i s _ m a t t h e w
#  v a i l 7 2 6 2
#  c h r i s t e n s e n _ a d a m
#  c h a m b e r s p a u l
#  c a r l r i p k a
#  t h o m p s o n
#  s h a f f e r n a t h a n
#  s c h l i c h t 4 1 8 3
#  h a w o r t h 1 9 4 8
#  b o n g a r d _ w a g l e
#  n a t h a n
#  g e o r g e   d a v i d s o n
#  j o h n 6 8 7 0
#  a s h w o o n   g e o r g e
#  b a x s t e r _ h a l
#  m o n t e   e b n e r
#  p a i s e r _ p a i s e r
#  d a n y o c u m
#  h e s c h e d w a r d
#  g e o r g e   s c h u t z
#  h a n c o c k _ w a l t e r
#  d o r a n
#  h y l a n   g e o r g e
#  o t t o
#  l e i s i n g e r _ j o e
#  t h o m a s 4 5 7 1
#  r a m a c h a n d r a n 2 3 5 3
#  d a v i d s o n _ s c h u s t e r
#  s c h l i c h t   d a v i d
#  n a t h a n 6 1 0 1
#  m i l l s   l a r r y
#  m a t t h e w
#  r o g e r s 4 4 9 5
#  j o e
#  2 9 0 7 2 0 9 7 9
#  s e l l o n _ c a s t
#  z i e g l e r   v i c t o r
#  8 4 1 7 7 7 0 8 3
#  r o o t   d a v i d
#  m a t t h e w
#  w a g l e _ f e r r y
#  p e t e r 7 1 0 1
#  w a l t e r p a i s e r
#  d a r n e l l
#  h a n k 2 0 5 1
#  t h o m a s   c a t a l d i
#  t h o m p s o n _ r o g e r
#  r o g e r 4 6 0 7
#  k e l l e r _ w a l t e r
#  m a t t h e w   u f l a n
#  j o e   k a s k e l
#  c a t a l d i d a v i d
#  r o g e r   u p s o n
#  t h o m a s p a i s e r
#  v i c t o r
#  o r w i g   l a r r y
#  f e r r o 7 1 0 8
#  j o h n s e n   m a t t h e w
#  e b n e r   f r e d
#  v i c t o r 9 4 9 3
#  p e t e r 6 7 0 3
#  s w e e n e y   j a c k
#  n a t h a n   m i l l e r
#  d e l o r e n z o t h o m a s
#  m i l l e r 6 5 0 9
#  n e l s o n g e o r g e
#  h a n c o c k 5 9 6 5
#  i l l i n g s w o r t h a a r o n
#  o s t r a n d e r
#  m o n t e 6 0 0 5
#  5 6 3 4 5 0 2 1
#  f i e t z e r
#  t y r e a r d o n
#  s w e e n e y   m a t t h e w
#  z e a s e r p e t e r
#  m o n t e h y d i n g e r
#  h a n k 5 4 1 9
#  c a n n o n 9 6 5
#  j o e
#  s h a f f e r   p a u l
#  l a w l e s s _ t h o m a s
#  c h a m b e r s
#  n a t h a n f e r r o
#  l e w i s   t h o m a s
#  m a r k 9 4 9 4
#  a n d e r s o n 2 7 5 3
#  d i n k i n s _ c a r l
#  3 7 9 5 1 2 4 1 5
#  p a u l m y e r s
#  s a w y e r
#  f r e d
#  g e o r g e v a l e n t e
#  n e l s o n   w a l t e r
#  d a n
#  v a i l   m o n t e
#  u p s o n _ d e i t z
#  v i c t o r w o o
#  f r e d   s o u l i s
#  v a i l _ d a v i d
#  d e l o r e n z o   f r a n k
#  v i c t o r
#  9 5 0 5 6 6 1
#  j a c k b a t e m a n
#  d a n   v o g a l
#  k a s s i n g   j o h n
#  v a n   z a n d t w a l t e r
#  9 8 4 5 2 1 2 6 2
#  c h a p m a n _ m o o r e
#  m o o r e 4 9 7 6
#  n a t h a n   o r t i z
#  9 9 7 0 4 0 4 4 6
#  a d a m
#  v a d e r _ k a l l e g
#  n a t h a n
#  t i m d u g e l m a n
#  j o h n 3 2 9 2
#  r i p k a
#  o s t r a n d e r 6 5 8 0
#  e b n e r   o t t o
#  c a n n o n   s t e v e
#  b e n m a r t i n
#  h a n k m i l l s
#  r i c e m a r k
#  m c g i n n i s _ s t e v e
#  d a v i d s c h i c k o w s k i
#  c h a m b e r s _ a l e x
#  j o e 3 2 1 8
#  d a v i d r a m a c h a n d r a n
#  e b n e r
#  s h a f f e r   a a r o n
#  j e n s o n _ w e i n s t e i n
#  l e i s i n g e r   a l e x
#  v o g a l
#  h a n k   s c h u t z
#  s a n d s t r o m   w a l t e r
#  a a r o n c h r i s t e n s e n
#  2 0 4 1 9 0 2 5 7
#  j o e m y e r s
#  j a c k t r e b i l
#  h a n k t i e r n a n
#  r o b e r t s i k e
#  e d w a r d   l i n d e
#  c e l e d o n   l a r r y
#  f e r r y   c a r l
#  v a l e n t e _ o r w i g
#  m a t t h e w p a i s e r
#  s c h m i t t   j o h n
#  b e n   r i c e
#  j a c k
#  c a n n o n 2 4 0 2
#  m a r k d e w a l t
#  p e t e r w e i n s t e i n
#  a l e x d u g e l m a n
#  s e v e r s o n   i k e
#  f l e t c h e r   o t t o
#  d a n 7 2 2 9
#  h a l p a i s e r
#  r e a m e r _ j a c k
#  m a r k d u f f m a n
#  a l e x 6 0
#  9 1 1 0 6 7 9 8 0
#  4 2 2 8 7 9 9 1 9
#  h a l 3 5 4 5
#  j o h n d e i t z
#  f e r r y   s t e v e
#  l e w i s   h a n k
#  w a k e f i e l d 2 7 5 3
#  t h o m a s   k a s k e l
#  2 3 6 8 3 7 1 9 6
#  e a s t m a n   t h o m a s
#  z e l l e r _ r i c e
#  w a k e f i e l d 2 5 4 2
#  w a g n e r 7 0 1 5
#  f r e d l e i s i n g e r
#  v i c t o r   l e i s i n g e r
#  p e t e r   b o n g a r d
#  v a l e n t e _ j o e
#  a l e x   l e p a g e
#  u l r i c h _ r o g e r
#  r o g e r   c h r i s t e n s e n
#  s o u l i s   b e n
#  4 4 6 1 8 2 2 5
#  l u l l o f f   e d w a r d
#  r e a m e r
#  f r a n k d u g a n
#  r e y e s b e n
#  m a r k
#  r o o t m a r k
#  a d a m   l i n d e
#  s c h i e b e l _ m a t t h e w
#  k a l l e g _ b a t e m a n
#  s t e v e   s c h i e b e l
#  6 0 3 0 4 0 8 4 3
#  t i m 1 2 7 9
#  s c h u s t e r f r a n k
#  t i m j u r g e n s o n
#  v a n d e r p o e l d a n
#  m c g i n n i s 5 9 3 9
#  t i s l e r   b e n
#  v i c t o r r e s n i c k
#  3 5 4 9 2 0 0 0 4
#  h a n k
#  j o h n
#  h a n k
#  i k e   w e i n s t e i n
#  t h o m p s o n   l a r r y
#  f r a n k   p a i s e r
#  4 7 1 1 9 8 5 4 2
#  c h r i s t e n s e n 4 8 1 3
#  8 9 4 7 0 5 3 9 5
#  i n g r a m i k e
#  v a i l _ s c h i c k o w s k i
#  s a n d s t r o m 6 4 9 6
#  a n d e r s o n   c a r l
#  a s h w o o n 8 2 6 9
#  d a n a n d e r s o n
#  d a v i d s o n 1 4 1 5
#  y a n g _ m i l l e r
#  l a w i c k i 7 3 5 9
#  a a r o n m o o r e
#  a s h w o o n _ l u l l o f f
#  p a u l
#  l a r r y
#  s o u k u p s t e v e
#  t i m r o g e r s
#  j o h n   c a n n o n
#  t r u s e l a   n a t h a n
#  j o e   s c h u t z
#  r o g e r   m i l l e r
#  s o n d e r l i n g   b e n
#  c a r l
#  2 5 6 3 0 0 4 7 6
#  s h a f f e r
#  1 8 3 7 0 2 8 4 5
#  a l e x t r u s s e l
#  m y e r s h a n k
#  t h o m p s o n   e d w a r d
#  q u i n n _ d e i t z
#  a d a m 6 5 9 0
#  m o o d y _ j o e
#  m a r k 1 6 9 3
#  m a r t i n   a l e x
#  c e l e d o n   i k e
#  s t e v e q u i z o z
#  d a v i s 9 1 8 4
#  j o h n s o n 4 1 2 0
#  s t e v e r a m a c h a n d r a n
#  v e n t o t l a _ m a r k
#  m i l l e r   c a r l
#  l a w i c k i   v i c t o r
#  c a r l   d o r a n
#  m a t t h e w m a r t i n
#  t i e r n a n   e d w a r d
#  u l r i c h r o g e r
#  h a n k   w o o
#  e d w a r d d e i t z
#  s c h i c k o w s k i   m a r k
#  s c h u s t e r   l a r r y
#  o t t o 1 7 4 5
#  s c h w a g e r _ j a g t a p
#  v a n d e r p o e l _ d a n
#  a l e x d u f f m a n
#  d u f f m a n
#  a l e x t i e r n a n
#  n a t h a n r e a r d o n
#  s c h u s t e r n a t h a n
#  k e l l e r   j o e
#  b e n   t r u s s e l
#  b o y d
#  j o h n s e n a a r o n
#  j a c k   o r w i g
#  d a n m a r t i n
#  b a t e m a n   p e t e r
#  p e t e r 1 2 0 4
#  7 5 0 1 2 8 7 6 4
#  z e a s e r   h a n k
#  s o u l i s v i c t o r
#  f r a n k s c h w a g e r
#  y o c u m   a a r o n
#  c h a p m a n o t t o
#  v a n d e r p o e l _ j a g t a p
#  d a n c h r i s t e n s e n
#  c a s a l
#  p a u l r e s n i c k
#  c a n n o n _ a l e x
#  p a u l r o g e r s
#  p e t e r   k a s k e l
#  d e w a l t   t h o m a s
#  e b n e r   l a r r y
#  v a d e r _ r o g e r
#  r i p k a
#  o t t o   c e l e d o n
#  6 9 1 3 5 5 1 3 8
#  a n d e r s o n _ a d a m
#  1 5 7 0 4 0 5 6 7
#  c h a p m a n
#  n o r q u i s t _ h a l
#  1 0 5 1 3 8 3 3 9
#  t y m y e r s
#  g e o r g e 1 0 9
#  w a g n e r _ e a s t m a n
#  d a n m i l l e r
#  j o h n 9 7 7 9
#  l a r r y m o o r e
#  c a t a l d i _ v i c t o r
#  o t t o d u f f m a n
#  m a r k w o o
#  s c h l i c h t
#  a a r o n
#  8 8 3 2 5 3 8 7 2
#  r o o t 7 6 6 8
#  k e l l e r 4 4 0 3
#  o t t o
#  w e i n s t e i n   c a r l
#  l a r r y 4 9 1 8
#  b e n c a s a l
#  c e l e d o n e d w a r d
#  j o e s o l o m a n
#  w a k e f i e l d _ d u g a n
#  8 7 7 9 3 2 6 3 1
#  b a u e r e d w a r d
#  w a l t e r m o o r e
#  7 8 0 8 6 2 3 0 3
#  m o n t e j o h n s e n
#  w o o _ d a n
#  a i k i n   f r e d
#  k a s s i n g
#  d a v i d   h a n c o c k
#  a l e x 6 0 2 2
#  i k e v o g a l
#  f r e d i r w i n
#  6 2 1 3 2 7 1 3 0
#  v e n t o t l a
#  d a v i d s o n
#  z e l l e r
#  6 8 1 3 0 5 2 1 0
#  o l s o n   t i m
#  s c h m i t t
#  k a l l e g   a d a m
#  a a r o n l e w i s
#  k n u t s o n e d w a r d
#  l e i s i n g e r _ t y
#  z e l l e r 3 5 6 7
#  o t t o
#  7 4 7 7 8 1 1 6 2
#  4 5 8 3 7 5 4 0 0
#  h e s c h r o g e r
#  l e w i s _ t i m
#  d a v i d
#  t i m 6 9 8 1
#  f e r r y
#  4 7 1 3 8 2 6 0 1
#  t i m y a n g
#  t u r c o 8 6 0 1
#  h a l n u t t l e
#  d a n h o f f m a n
#  l e w i s
#  s o l o m a n _ h a w o r t h
#  v o g a l h a l
#  m a r t i n _ j o h n s o n
#  t h o m p s o n _ s h a f f e r
#  r i p k a 9 4 7
#  z e l l e r 1 9 5 7
#  a a r o n d i n k i n s
#  3 9 9 1 6 3 7 8 3
#  p a u l c h a p m a n
#  d a n
#  c a n n o n   r o g e r
#  l a r r y 2 5 6 2
#  r o g e r 8 2 6 9
#  f e r r y _ j u r g e n s o n
#  o t t o 4 8 1
#  e d w a r d   s o u l i s
#  n a t h a n
#  c a s w e l l 6 7 2 6
#  w a l t e r   s e v e r s o n
#  n u g e n t
#  n o r q u i s t   c a r l
#  h a n k l a w i c k i
#  t y   r o b e r t s
#  r o g e r   o r t i z
#  p e t t i g r e w _ y a t e s
#  8 1 3 6 8 8 3 6 5
#  d a v i s   p a u l
#  a l e x l i n d e
#  l e w i s o t t o
#  n a t h a n 7 5 6 6
#  h a n k y o c u m
#  o r t i z _ w a g l e
#  u p s o n   f r e d
#  s e l l o n   a a r o n
#  m o n t e h y l a n
#  s c h m i t t 9 8 8 0
#  d a v i d s o n _ d a r n e l l
#  t h o m a s m a k i
#  b o w e r s   v i c t o r
#  r e y e s _ j u r g e n s o n
#  r a m a c h a n d r a n
#  t i m s o l b e r g
#  d i n k i n s   t h o m a s
#  u d d i n
#  d a v i d
#  v i c t o r s a n d s t r o m
#  v e n t o t l a   o t t o
#  d o r a n   m o n t e
#  r o b e r t s _ m a t t h e w
#  r i c e _ o t t o
#  r o o t a d a m
#  r i c e 7 6 8 8
#  y a n g   m a r k
#  u f l a n
#  m a t t h e w s c h m i t t
#  s c h w a g e r   i k e
#  i k e j o h n s e n
#  y a n g _ h y d i n g e r
#  l e p a g e 6 0 0 1
#  t h o m a s l a w i c k i
#  m a t t h e w   r e a m e r
#  n o r q u i s t   s t e v e
#  n a t h a n a n d e r s o n
#  d a n   h a n c o c k
#  s o l b e r g _ a a r o n
#  4 0 6 8 7 6 9 3 2
#  m a t t h e w j u r g e n s o n
#  j a c k 9 9 3 3
#  r o g e r c h a p m a n
#  m a k i _ r e y e s
#  j o h n j a g t a p
#  h o f f m a n r o g e r
#  j a c k 7 9
#  v a i l t h o m a s
#  w a g l e b e n
#  t u r c o
#  k a s k e l   b e n
#  f r a n k   o r y
#  r a m a c h a n d r a n 5 9 5 6
#  t a n d y _ a d a m
#  d e l o r e n z o
#  m y e r s _ r a m a c h a n d r a n
#  a l e x
#  w e i n s t e i n m a r k
#  s o n d e r l i n g   f r e d
#  j o e 2 6 2 3
#  u l r i c h   j o e
#  s w e e n e y _ d e i t z
#  d a n
#  u d d i n 4 5 9 7
#  y a t e s   p a u l
#  b a t e m a n
#  t u r c o _ d a v i d
#  m a k i i k e
#  2 8 6 4 7 9 3 0 1
#  h y d i n g e r
#  f r i c k   l a r r y
#  m o n t e b a x s t e r
#  a l e x s o u l i s
#  h a w o r t h
#  e b n e r _ d u g a n
#  o t t o 7 6 0 0
#  a l e x
#  s o u k u p
#  7 9 3 2 6 6 2 1 2
#  t i m
#  k n u t s o n   d a v i d
#  c a t a l d i   w a l t e r
#  h a l   s c h m i t t
#  m a r k
#  8 8 9 9 7 2 3 4 1
#  6 8 6 6 8 6 0 2 6
#  m a r k t u r c o
#  c a r l 9 7 5 3
#  s c h i e b e l   m a t t h e w
#  m a t t h e w 7 2 8
#  t h o m a s s c h w a g e r
#  j a c k   y a t e s
#  t r e b i l d a v i d
#  o r t i z
#  h a n k s w e e n e y
#  p a u l
#  d u f f m a n e d w a r d
#  y a n g
#  b a x s t e r _ m o o d y
#  7 1 5 2 1 0 3 2 0
#  y a n g   t h o m a s
#  d u g e l m a n   g e o r g e
#  d u f f m a n _ v i c t o r
#  w o o _ b o w e r s
#  z i e g l e r   v i c t o r
#  f l e t c h e r   m a t t h e w
#  p e t e r
#  c a n n o n   m a r k
#  g e o r g e
#  z i e g l e r 2 5 2 8
#  r o g e r 3 1 2 6
#  o r w i g _ m c c o r d
#  d a n 3 8 4
#  r o g e r r e a m e r
#  t r u s s e l   o t t o
#  9 9 5 2 9 1 4 1
#  m c c o r d   m a r k
#  m a r t i n t y
#  c e l e d o n 8 7 0 5
#  d a r n e l l   h a l
#  b e n
#  a d a m   y a t e s
#  a a r o n
#  w o o 2 9 8 9
#  p e t e r 8 2 7 9
#  h a w o r t h _ d o r a n
#  8 6 3 1 0 3 2 1 5
#  t i m 7 5 0 2
#  n u t t l e 2 3 9 0
#  4 1 3 5 2 6 6 9 2
#  k n u t s o n   a d a m
#  j o h n
#  l a w i c k i _ s c h l i c h t
#  n a p i e r _ j a c k
#  r i p k a 6 2 7 8
#  j o e
#  j o e h e s c h
#  t i m   c a s t
#  t i s l e r   b e n
#  n a p i e r   l a r r y
#  s t e v e h y l a n
#  c a r l 5 2 4 7
#  n e l s o n _ c a s a l
#  3 6 8 9 1 6 1 4 6
#  f e r r y
#  k n u t s o n   b e n
#  l u l l o f f _ s t a h l
#  8 0 0 8 3 4 0 2 7
#  8 8 9 5 0 0 0 0 5
#  h a l y o c u m
#  w o o _ m y e r s
#  6 3 3 1 8 8 0 9
#  f r e d p a k
#  t y
#  c h r i s t e n s e n
# ...
#  5 4 2 9 6 0 6 4 3
#  k e l l e r 5 3 7 6
#  j a g t a p _ m c g i n n i s
#  j a g t a p   p a u l
#  d a n l a w i c k i
#  c a r l   h a w o r t h
#  f l e t c h e r s t e v e
#  f r a n k l e w i s
#  a n d e r s o n
#  h e s c h 6 5 5 3
#  b e n
#  o r w i g   m o n t e
#  h e s c h   e d w a r d
#  s o u l i s   m a t t h e w
#  d a n   c h a p m a n
#  d a n 7 7 0 1
#  h y d i n g e r _ n a t h a n
#  g e o r g e l a w l e s s
#  8 8 1 4 9 3 7 3 6
#  s t e v e c a s t
#  2 1 6 7 0 6 6
#  d o r a n   h a l
#  d o r a n   m o n t e
#  m o n t e u p s o n
#  p e t e r   c a n n o n
#  c a r l   r a m a c h a n d r a n
#  p e t e r d a v i d s o n
#  r o g e r s _ r o g e r
#  d a n f e r r y
#  u d d i n _ j o h n
#  q u i n n   s t e v e
#  m a r t i n 2 6 0
#  n a t h a n p e t t i g r e w
#  6 5 8 3 9 5 7 1 9
#  v a l e n t e   a d a m
#  d a n s c h i e b e l
#  h a n k l e i s i n g e r
#  h a n k s a w y e r
#  h e s c h   b e n
#  t i m   l a w l e s s
#  c h r i s t e n s e n _ d a n
#  f r e d 4 0 1 3
#  d a v i d o r w i g
#  e d w a r d d a r n e l l
#  d e i t z f r e d
#  y a n g   f r e d
#  l a r r y
#  t r u s e l a
#  m o n t e o r y
#  w e i s s   t y
#  h a w o r t h   i k e
#  w e i s s d a n
#  m o n t e   o r w i g
#  m o o d y 1 4 2 2
#  s c h l i c h t _ w o o
#  j o h n s e n
#  f r e d   m o o r e
#  r o g e r 9 7 5 5
#  d a v i s   d a n
#  m y e r s
#  g e o r g e 6 9 2 9
#  v e n t o t l a
#  g e o r g e b o y d
#  j o h n s o n _ w o o
#  d a v i d t a p i a
#  p a u l 7 5 9 5
#  w e i n s t e i n _ l a w l e s s
#  d e l o r e n z o
#  f r e d n e l s o n
#  t y q u i n n
#  j o h n s o n s t e v e
#  v a d e r _ m o n t e
#  f e r r o _ n u g e n t
#  q u i n n   d a v i d
#  c h a m b e r s
#  t i e r n a n   f r e d
#  y o c u m _ o r y
#  r o g e r   z e a s e r
#  p e t e r 8 4 0 4
#  b e n a n d e r s o n
#  3 0 0 7 9 9 9 2 7
#  w e i s s   t y
#  r o o t b e n
#  v a i l a a r o n
#  r o g e r s _ o r y
#  m c g i n n i s
#  r o g e r 9 7 7 0
#  f l e t c h e r _ j o h n
#  a d a m s t a h l
#  w o o a a r o n
#  s a w y e r   h a l
#  2 8 7 1 5 7 7 9 8
#  c a t a l d i 8 4 5 7
#  t h o m p s o n _ s o u k u p
#  t y 7 5 6 5
#  f r e d   s c h i c k o w s k i
#  a s h w o o n j a c k
#  r o g e r 2 6 1 7
#  s t a h l
#  s c h l i c h t 2 0 4 7
#  l u l l o f f   g e o r g e
#  o s t r a n d e r   a a r o n
#  t h o m a s
#  o l s o n
#  h a n k y o c u m
#  f r a n k b o w e r s
#  a a r o n j o h n s e n
#  c a n n o n   a a r o n
#  e d w a r d
#  a i k i n   r o g e r
#  c h a p m a n _ w a l t e r
#  l i n d e   g e o r g e
#  i r w i n _ n e l s o n
#  j a c k m a k i
#  f e r r o g e o r g e
#  f r i c k 5 8 5 3
#  a d a m
#  s o u l i s _ q u i n n
#  f r e d
#  g e o r g e f e r r y
#  m o n t e
#  p a k   f r a n k
#  h a l   b a t e m a n
#  f r e d t i e r n a n
#  v i c t o r 7 3 2 4
#  v o g a l _ r o g e r s
#  f e r r o   t h o m a s
#  z i e g l e r p a u l
#  b o w e r s 4 0 7 4
#  j o h n c h r i s t e n s e n
#  s t e v e   h o f f m a n
#  p e t e r
#  d u g a n 4 6 3 8
#  m i l l e r _ k a l l e g
#  d e i t z 8 9 9 3
#  r e y e s
#  a l e x q u i n n
#  d e l o r e n z o   s t e v e
#  5 6 9 4 3 3 6 6
#  z i e g l e r   c a r l
#  i k e   c a s t
#  t r u s e l a   f r e d
#  e d w a r d 4 0 1 6
#  n u t t l e _ a d a m
#  f e r r o 3 8 9 1
#  z i e g l e r _ d a v i d
#  6 3 4 7 1 0 2 7 4
#  m a k i _ c h a p m a n
#  t i m
#  w a g l e 2 3 5 3
#  s w e e n e y   p e t e r
#  d a n r a m a c h a n d r a n
#  s c h m i t t 9 7 3 1
#  w a g l e
#  o l s o n   f r a n k
#  t u r c o   n a t h a n
#  r e a r d o n   t y
#  k a l l e g _ m o n t e
#  b a t e m a n v i c t o r
#  f r a n k t u r c o
#  h a n k r o b e r t s
#  m o o d y b e n
#  c a r l   c a t a l d i
#  t i s l e r   j a c k
#  s t a h l _ m o n t e
#  a l e x v a i l
#  s o l o m a n   j o e
#  4 0 5 5 4 3 6 6 9
#  o s t r a n d e r _ c h a m b e r s
#  v a i l
#  i k e
#  q u i n n _ w e i n s t e i n
#  h a l
#  r e a m e r _ h y l a n
#  g e o r g e   u p s o n
#  l a r r y s c h l i c h t
#  n a t h a n
#  w a l t e r   s c h m i t t
#  2 0 5 1 9 8 7 3 4
#  s a g a r _ m c g i n n i s
#  l u l l o f f 3 7 7 7
#  p e t e r v o g a l
#  s a w y e r   m a t t h e w
#  f r e d   d i n k i n s
#  c e l e d o n s t e v e
#  s o l o m a n o t t o
#  g e o r g e   z i e g l e r
#  o r w i g d a v i d
#  s t e v e 1 3 2
#  i k e l e i s i n g e r
#  f i e t z e r   t h o m a s
#  2 9 8 8 3 4 4 0 7
#  m a t t h e w v a l e n t e
#  m o n t e c a s a l
#  b o w e r s c a r l
#  t y   r o b e r t s
#  s o u k u p 3 9 5 3
#  h a n k d u f f m a n
#  i n g r a m _ r e y e s
#  z e a s e r j o e
#  p a u l
#  6 2 8 1 2 3 6 9 7
#  s o n d e r l i n g r o g e r
#  n a p i e r _ r o g e r
#  f r e d   c a t a l d i
#  n o r q u i s t 7 4 7 5
#  s t a h l
#  p e t t i g r e w   f r e d
#  d e l o r e n z o
#  s t e v e 8 9 4 4
#  i l l i n g s w o r t h _ b a x s t e r
#  a d a m
#  c h a p m a n _ w a k e f i e l d
#  f r e d
#  m c c o r m a c k   m a r k
#  f e r r o _ m o o r e
#  9 6 7 1 6 2 8 7 1
#  t h o m a s b o n g a r d
#  s c h u s t e r _ p a u l
#  u l r i c h   f r a n k
#  l a r r y 6 9 8 0
#  k e l l e r 7 3 9 3
#  t y b a u e r
#  t h o m p s o n t h o m a s
#  m c c o r d m o n t e
#  r e y e s
#  r e a r d o n _ s c h i c k o w s k i
#  7 9 8 5 7 6 9 2 0
#  t r u s e l a m a t t h e w
#  c h a m b e r s _ t a p i a
#  v a i l   j o h n
#  a a r o n 8 2 6 8
#  w a g l e t y
#  4 9 4 4 7 8 9 1 1
#  s o u k u p _ j o n e s
#  s c h u t z 1 1 2
#  o r w i g   o t t o
#  1 4 7 1 9 3 3 7 3
#  4 5 8 6 3 4 6 2
#  j e n s o n r o g e r
#  l a w i c k i
#  m o o r e _ w a l t e r
#  i n g r a m   r o g e r
#  d a v i d s e v e r s o n
#  t i m 4 7 0 8
#  j o e
#  e b n e r f r a n k
#  f r i c k
#  i k e   l u l l o f f
#  r a m a c h a n d r a n   n a t h a n
#  d a n   s h a f f e r
#  n u g e n t 2 0 1 0
#  s o l b e r g _ i k e
#  s e l l o n   p e t e r
#  3 4 5 6 7 9 7 4 0
#  r e s n i c k _ s o u l i s
#  c a s t   a d a m
#  d a v i d 1 2 2 3
#  v a i l _ m c c o r m a c k
#  d o r a n 2 2 5 1
#  d u f f m a n _ o t t o
#  r i p k a d a v i d
#  t h o m p s o n _ l a r r y
#  s c h l i c h t   v i c t o r
#  m y e r s _ n u g e n t
#  n e l s o n _ u f l a n
#  r o g e r s a n d s t r o m
#  s c h u t z _ w a k e f i e l d
#  b o n g a r d 9 7 5 2
#  i k e
#  e d w a r d
#  p e t e r
#  s o n d e r l i n g 1 5 4 4
#  d e l o r e n z o 8 3 7 8
#  d a v i d u p s o n
#  v i c t o r
#  h o f f m a n _ h a l
#  s o l b e r g 9 1 0 4
#  v a l e n t e 7 2 4 1
#  j o n e s   g e o r g e
#  o t t o 1 8 3 5
#  s c h w a g e r
#  b a t e m a n   w a l t e r
#  l a r r y m c g i n n i s
#  t h o m a s   r i c e
#  b e n   b a u e r
#  t i e r n a n   p e t e r
#  t y
#  l a r r y s a g a r
#  t r u s s e l 4 7 6 7
#  u f l a n
#  j a c k m a r t i n
#  d a v i d
#  c a r l w a g n e r
#  a a r o n
#  6 2 4 1 6 8 4 2
#  u d d i n   p e t e r
#  i l l i n g s w o r t h t i m
#  m o o d y _ j o h n
#  a n d e r s o n v i c t o r
#  j a c k
#  b a x s t e r _ s c h u t z
#  i k e s c h m i t t
#  a d a m r o g e r s
#  j a c k z e a s e r
#  3 9 3 1 7 3 3 4 8
#  t h o m a s   m o o r e
#  w a l t e r   k a s s i n g
#  f r e d 2 9 1 9
#  t i e r n a n   m a t t h e w
#  c a s t
#  c a r l
#  p a u l 7 3 9 4
#  n u g e n t l a r r y
#  r i p k a 8 7 2 8
#  a a r o n
#  l a w i c k i 1 3 5 7
#  s o u k u p   w a l t e r
#  u p s o n l a r r y
#  a i k i n   h a l
#  n u g e n t 4 4 9 3
#  m a t t h e w q u i z o z
#  v i c t o r   h o f f m a n
#  k a s k e l _ j o e
#  s o l b e r g   s t e v e
#  s c h l i c h t
#  v i c t o r
#  1 1 7 8 5 5 1 5 3
#  l a w l e s s   a l e x
#  b a x s t e r _ h a n k
#  t h o m a s p a i s e r
#  j o h n b o n g a r d
#  d u g e l m a n _ h a n k
#  v i c t o r s e v e r s o n
#  s e v e r s o n m a r k
#  h a n c o c k _ s t a h l
#  o s t r a n d e r   a l e x
#  c a r l s w e e n e y
#  5 6 2 0 9 0 8 2 8
#  b e n   w a k e f i e l d
#  r e a r d o n   f r e d
#  s c h i c k o w s k i 3 1 2 0
#  w a k e f i e l d   e d w a r d
#  r o g e r 7 3 4 5
#  o r t i z
#  s o u l i s m a r k
#  j o h n v a i l
#  p e t e r n a p i e r
#  b a t e m a n
#  d o r a n   w a l t e r
#  e b n e r
#  j e n s o n _ s o l b e r g
#  r a m a c h a n d r a n _ o r w i g
#  p e t e r v e n t o t l a
#  v i c t o r   c h a p m a n
#  m a k i   r o g e r
#  s o l o m a n _ q u i z o z
#  s w e e n e y   f r e d
#  p a u l u p s o n
#  p e t e r
#  u l r i c h   d a n
#  e b n e r _ w a l t e r
#  w a l t e r
#  a a r o n m c c o r d
#  s e l l o n   j a c k
#  p a u l   t u r c o
#  a d a m
#  h a l
#  f r e d r i c e
#  b o w e r s e d w a r d
#  d a r n e l l
#  f r i c k 6 9
#  t i m o r t i z
#  m a r k 2 8 7
#  l e i s i n g e r a a r o n
#  a a r o n
#  l i n d e
#  y a n g   w a l t e r
#  m c c o r m a c k
#  c a t a l d i _ v o g a l
#  w a l t e r   s c h u s t e r
#  6 2 9 6 7 9 7 0 8
#  v i c t o r   n u t t l e
#  r o o t   d a n
#  a s h w o o n
#  k a s s i n g _ j o e
#  s c h u s t e r _ r o o t
#  6 8 1 6 1 7 2 7 9
#  o r w i g
#  r o g e r h a w o r t h
#  t u r c o _ e a s t m a n
#  z i e g l e r 8 0 3 2
#  s o u k u p
#  s t e v e m i l l e r
#  9 7 2 3 4 8 4 2
#  r e a r d o n 9 2 1 2
#  s a g a r
#  p a u l   m y e r s
#  j a c k 7 7 8 7
#  j a g t a p _ l a r r y
#  f r e d   a i k i n
#  o t t o   l e i s i n g e r
#  y a t e s _ t h o m a s
#  k n u t s o n _ t h o m a s
#  d a v i s   m o n t e
#  v a d e r _ a l e x
#  n u t t l e 1 6 2 6
#  7 3 8 7 3 1 6 1 3
#  h e s c h   h a n k
#  m o n t e 6 1 9 8
#  a l e x h y d i n g e r
#  c a s w e l l   a a r o n
#  d a n c a s a l
#  s c h u s t e r _ t i e r n a n
#  v i c t o r k e l l e r
#  i l l i n g s w o r t h   m o n t e
#  j o n e s
#  p e t e r
#  h o f f m a n 9 2 5 4
#  s a n d s t r o m 6 0 2 1
#  2 6 0 1 2 3 1 8 1
#  m o o d y _ l a w l e s s
#  6 2 2 9 2 1 6 6 5
#  w a g n e r
#  4 9 8 2 0 2 2 1 2
#  t h o m p s o n 2 8 8 6
#  a l e x f r i c k
#  z e l l e r   m a t t h e w
#  t h o m a s j a g t a p
#  s t a h l _ s o l b e r g
#  r e s n i c k
#  t i s l e r   l a r r y
#  8 8 1 6 0 6 4 0 8
#  h a n k 4 6 1 6
#  t h o m a s   r e a m e r
#  t u r c o
#  j o n e s   r o g e r
#  m a t t h e w   d o r a n
#  f r i c k _ s t e v e
#  e d w a r d d i n k i n s
#  3 5 8 3 4 0 5 9
#  p a u l 7 8 7 3
#  u p s o n _ q u i n n
#  s e l l o n   f r a n k
#  p e t e r y o c u m
#  r i c e   a a r o n
#  7 1 4 2 1 5 7 4 2
#  2 0 0 9 1 2 7 0 3
#  5 3 7 9 1 2 9 2 8
#  h a n k 2 7 6 3
#  r o g e r 4 9 1 1
#  n a t h a n b a x s t e r
#  t h o m p s o n l a r r y
#  f r a n k l e p a g e
#  e b n e r _ c a s a l
#  m o o d y r o g e r
#  m a k i   a l e x
#  j o h n s o n   h a n k
#  d e l o r e n z o _ a d a m
#  d a n   d e l o r e n z o
#  k n u t s o n d a v i d
#  h a l 2 2 3 1
#  q u i n n _ a i k i n
#  t r e b i l r o g e r
#  t i e r n a n m a r k
#  o l s o n   g e o r g e
#  r e a m e r
#  h a w o r t h 9 9 9 1
#  r o b e r t s m a r k
#  j a c k
#  t r u s s e l
#  m c g i n n i s _ o r w i g
#  j a c k u p s o n
#  n u g e n t 6 9 7 6
#  m a r t i n _ k a s k e l
#  d a v i d t u r c o
#  h a l q u i n n
#  v a i l   f r a n k
#  n u t t l e s t e v e
#  v a i l
#  n a t h a n   y o c u m
#  v i c t o r k n u t s o n
#  k a s k e l
#  7 2 0 3 2 8 8 8
#  j o e   n u t t l e
#  n a t h a n 3 4 0 3
#  a a r o n
#  c h a p m a n   m o n t e
#  a a r o n 1 5 7 3
#  b e n m o o d y
#  v a n   z a n d t 9 3 5 6
#  t r e b i l   a a r o n
#  9 1 6 0 8 5 6 5 3
#  k n u t s o n   t i m
#  s c h i c k o w s k i _ t a p i a
#  j o h n 5 1 4 7
#  f r e d l a w i c k i
#  h e s c h
#  n a t h a n
#  r e a r d o n   b e n
#  e d w a r d a n d e r s o n
#  k e l l e r h a l
#  k a l l e g _ n a t h a n
#  r o g e r   d i n k i n s
#  j o h n s e n _ c a t a l d i
#  h a l   w a g n e r
#  b o n g a r d
#  m c c o r d
#  b o w e r s _ u l r i c h
#  n e l s o n r o g e r
#  s t e v e v a n   z a n d t
#  l e w i s _ o r t i z
#  r e y e s _ s t e v e
#  m a r t i n   e d w a r d
#  r o b e r t s _ w a l t e r
#  d a v i d s o n   v i c t o r
#  i k e 1 5 2 6
#  7 6 1 3 4 9 9 1
#  a a r o n   p a k
#  8 1 9 3 7 8 0 3 6
#  t y 9 3 6 1
#  f r a n k w o o
#  s t e v e v a n   z a n d t
#  s o l b e r g
#  s t a h l   a d a m
#  t u r c o
#  a s h w o o n t h o m a s
#  k a s k e l   t i m
#  l a r r y 8 4 1 8
#  t a n d y t y
#  b a u e r _ r i p k a
#  m o o d y   v i c t o r
#  8 6 6 9 2 6 9 3 1
#  v a n   z a n d t _ p a u l
#  h y l a n _ j o h n
#  h o f f m a n _ d a r n e l l
#  s o n d e r l i n g 7 3 0 6
#  m i l l s _ d e l o r e n z o
#  h a n k
#  j o h n s o n _ j o e
#  l a w i c k i
#  j o h n s o n _ y a t e s
#  z e l l e r _ t y
#  t h o m a s c a s a l
#  w a g l e   d a n
#  r e a m e r _ j o n e s
#  c a r l 3 0 6 0
#  r o g e r 6 8 9 2
#  p e t e r v a d e r
#  t h o m p s o n
#  w a g l e h a l
#  p a u l h y d i n g e r
#  t a p i a _ j o h n
#  l a r r y
#  a n d e r s o n e d w a r d
#  t i m s e l l o n
#  t i m   f i e t z e r
#  p a k a l e x
#  m a r k p a k
#  v i c t o r d i n k i n s
#  k a s k e l _ d u f f m a n
#  p a u l 9 9 5 9
#  i k e   m a k i
#  m o o r e f r a n k
#  4 0 6 3 9 2 4 2 8
#  o r y _ n u g e n t
#  s o l o m a n g e o r g e
#  b a t e m a n _ w e i n s t e i n
#  z e a s e r
#  u l r i c h t y
#  i r w i n   p a u l
#  a l e x m c g i n n i s
#  c a t a l d i   t i m
#  h a l r i c e
#  n e l s o n   s t e v e
#  v a i l _ c h a p m a n
#  s c h i e b e l t h o m a s
#  i k e   h a n c o c k
#  r o g e r
#  n u g e n t _ f l e t c h e r
#  m a k i 8 6 9 2
#  a d a m
#  r o g e r   m a k i
#  s e l l o n   d a v i d
#  a d a m
#  t h o m a s y a t e s
#  c e l e d o n _ w a l t e r
#  k a s s i n g 4 4 9 5
#  b o y d _ g e o r g e
#  b o w e r s _ e b n e r
#  j a c k 9 3 5 2
#  l e w i s d a n
#  s c h m i t t   r o g e r
#  m c c o r m a c k m a r k
#  t i m b a u e r
#  r o g e r 3 4 9
#  r e a m e r _ r o g e r s
#  s o u l i s f r e d
#  v a d e r   t i m
#  o r y   h a l
#  w a g n e r t h o m a s
#  a d a m j a g t a p
#  p a u l   r e a m e r
#  a d a m
#  t y
#  e d w a r d
#  d o r a n 2 2 8 6
#  i r w i n h a l
#  t y s c h w a g e r
#  g e o r g e m i l l s
#  w a g l e 3 8 9
#  e d w a r d f e r r o
#  a d a m o s t r a n d e r
#  k e l l e r   t y
#  2 5 8 5 4 6 7 4 8
#  b e n c a s w e l l
#  s t e v e 1 8 6 2
#  h a l t u r c o
#  t i e r n a n _ c a s a l
#  s o l b e r g 4 1 3 9
#  d a v i d s o n   o t t o
#  a l e x d o r a n
#  t h o m a s
#  m o n t e   u p s o n
#  f r i c k _ c a n n o n
#  o t t o
#  s c h u t z   s t e v e
#  i k e n o r q u i s t
#  h a l
#  u l r i c h   t h o m a s
#  v a d e r _ c a s a l
#  a a r o n
#  a n d e r s o n _ a a r o n
#  a i k i n 8 1 8 6
#  h o f f m a n _ v i c t o r
#  l a r r y t h o m p s o n
#  e b n e r j o h n
#  f r a n k   n e l s o n
#  e b n e r _ r e a m e r
#  t r u s e l a _ p a u l
#  d i n k i n s a l e x
#  j a c k 3 0 8 3
#  c a s a l
#  f r e d
#  d a v i s g e o r g e
#  j a g t a p
#  j o e 1 0 6 8
#  w a g n e r   r o g e r
#  f r e d v a l e n t e
#  h y l a n   c a r l
#  2 7 0 8 0 4 9 5 1
#  u d d i n 1 8 7 5
#  t u r c o   c a r l
#  h o f f m a n
#  j o e   r o g e r s
#  s c h m i t t _ l a r r y
#  8 7 9 4 4 2 0 1 4
#  c a r l s o l o m a n
#  n a t h a n 6 1 1 5
#  f r a n k
#  n o r q u i s t _ s t e v e
#  d e l o r e n z o _ p e t e r
#  p a u l
#  o r w i g
#  d i n k i n s   a d a m
#  t i s l e r d a n
#  e d w a r d 6 1 7 4
#  m o n t e p e t t i g r e w
#  s c h u t z l a r r y
#  z e a s e r t i m
#  w a l t e r   k a s s i n g
#  f e r r o   d a v i d
#  s c h m i t t _ s c h i e b e l
#  i k e t h o m p s o n
#  m a r t i n   b e n
#  b e n v e n t o t l a
#  z i e g l e r _ s o l o m a n
#  d a v i d s o n _ r o g e r s
#  g e o r g e
#  r a m a c h a n d r a n 4 3 1
#  p a u l o s t r a n d e r
#  t y s e v e r s o n
#  e d w a r d o r t i z
#  h a l 5 9 9 9
#  c h r i s t e n s e n   d a v i d
#  m a r k
#  b o n g a r d   p a u l
#  m o o d y 3 4 1 7
#  t r e b i l _ b o w e r s
#  p a k 9 2 6 7
#  8 8 3 8 8 6 4 9 9
#  p e t e r k n u t s o n
#  m a r k
#  6 6 0 6 9 4 5 1 6
#  l a r r y
#  w a g n e r   o t t o
#  r i p k a 1 0 9 6
#  b o w e r s   o t t o
#  p e t e r 2 8 5 9
#  u l r i c h _ f r e d
#  d u g e l m a n _ c a r l
#  8 0 1 1 4 0 7 5 2
#  s c h u t z _ o t t o
#  v a d e r   l a r r y
#  j u r g e n s o n   a a r o n
#  s t a h l _ t y
#  l a w i c k i m a t t h e w
#  k a s s i n g   v i c t o r
#  h a l b o n g a r d
#  s o u k u p   r o g e r
#  7 3 3 0 9 5 7 0 0
#  j a c k   s w e e n e y
# 10000
