# %%
y=5+3
y
# Out:
# 8

# %%
y=6
y
# Out:
# 6

# %% [markdown]
# # Heading1
# ### Heading2

# %% [markdown]
# $ x + 5 $

# %% [markdown]
# open link [reference](https://www.google.com/search?q=cats+and+dogs&sxsrf=ALiCzsYLUHImDxiRJkEtYlD1jNHG31DzIw:1651834201863&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiqs9H22cr3AhWEu6QKHQuEC-EQ_AUoAnoECAMQBA&biw=1848&bih=948&dpr=1)

# %% [markdown]
# ![1_XEzukXOEUudcXkyrouu3vw.jpeg](attachment:1_XEzukXOEUudcXkyrouu3vw.jpeg)
