# %% [markdown]
# ### Targeted information retrieval

# %% [markdown]
# We have seen how to parse a webpage, which retrieves the information without distinction.
#
# But, in general, the purpose of scraping is to automate the collection of targeted information on the web.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Let's say I want to scrape the description of the latest movies released in theaters.
#
# So we'll go to the Allociné website and try to find the tags that will give me links to the specific pages of these movies to get their summaries.

# %% [markdown]
# #### Recovery of the url of the pages of films newly released in the theaters

# %%
url = "http://www.allocine.fr/"
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content, "lxml")
soup
# Out:
# http://www.allocine.fr/ 200
# <!DOCTYPE html>
# <html lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="index,follow,max-snippet:-1" name="robots"/>
# <title>AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="AlloCine" name="author"/>
# <meta content="France" name="country"/>
# <meta content="48.87078;2.30447" name="geo.position"/>
# <meta content="FR" name="geo.country"/>
# <meta content="48.87078;2.30447" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." name="description"/>
# <meta content="ix8k18CxRg4EHoLaobgVaujTuv5nlo-QZK12lanw2pk" name="google-site-verification"/> <meta content="AlloCiné" property="og:site_name"/>
# <meta content="AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD" property="og:title"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." property="og:description"/>
# <meta content="99197768694" property="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@allocine" name="twitter:site"/>
# <meta content="AlloCiné : Cinéma, Séries TV, BO de films et séries, Vidéos, DVD et VOD" name="twitter:title"/>
# <meta content="AlloCiné, le site de référence du cinéma et des séries tv ! Découvrez notre recherche d'horaires de films, le programme tv de vos séries préférées, l'actualité ciné et séries, les émissions AlloCiné, les dernières bandes-annonces, et plus encore." name="twitter:description"/>
# <meta content="" name="twitter:image"/>
# <meta content="allocine" name="twitter:app:name:iphone"/>
# <meta content="allocine" name="twitter:app:name:ipad"/>
# <meta content="allocine" name="twitter:app:name:googleplay"/>
# <meta content="allocine://open/" name="twitter:app:url:iphone"/>
# <meta content="allocine://open/" name="twitter:app:url:ipad"/>
# <meta content="allocine://open/" name="twitter:app:url:googleplay"/>
# <meta content="351184863" name="twitter:app:id:iphone"/>
# <meta content="351184863" name="twitter:app:id:ipad"/>
# <meta content="com.allocine.androidapp" name="twitter:app:id:googleplay"/>
# <meta content="app-id=351184863, app-argument=allocine://open/" name="apple-itunes-app"/>
# <meta content="107276450147" property="fb:pages"/>
# <link href="https://assets.allocine.fr" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.allocine.fr/skin/font/icon/font-icon-9f5f785d6d.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey-5de8867c13.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.allocine.fr/js/website/website-common.93bf89cf686ddeb87612.js" rel="preload"/>
# <link as="script" href="https://assets.allocine.fr/js/website/home.c86c9eb7a778c163256a.js" rel="preload"/>
# <link href="https://sdk.privacy-center.org/" rel="preconnect"/>
# <link as="image" href="https://fr.web.img4.acsta.net/img/17/b5/17b500d7d98a542b80e51db26c003c09.jpg" rel="preload"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\00201c" "\00201d" "\002018" "\002019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.icon:after,.icon:before,.more-trigger:after{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}@font-face{font-family:font-icon;src:url(https://assets.allocine.fr/skin/font/icon/font-icon-9f5f785d6d.woff2) format("woff2"),url(https://assets.allocine.fr/skin/font/icon/font-icon-892c1815af.woff) format("woff"),url(https://assets.allocine.fr/skin/font/icon/font-icon-7e32a67362.ttf) format("truetype");font-weight:400;font-style:normal}.footer-logo-WB{background-position:-284px 0;width:112px;height:29px}.footer-logo-boxoffice{background-position:-925px 0;width:315px;height:26px}.footer-logo{background-position:-398px 0;width:120px;height:34px}.header-arrow--bottom--black{background-position:0 0;width:16px;height:16px}.header-back{background-position:-92px 0;width:46px;height:46px}.header-burger{background-position:-140px 0;width:46px;height:46px}.header-home{background-position:-18px 0;width:16px;height:16px}.header-logo--primary{background-position:-661px 0;width:262px;height:74px}.header-logo-userspace{background-position:-520px 0;width:139px;height:39px}.header-minify{background-position:-188px 0;width:46px;height:46px}.header-music{background-position:-36px 0;width:16px;height:16px}.header-netflix{background-positio ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'allocine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min\u002D760736ff24.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.allocine.fr/apple-touch-icon/allocine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/allocine" rel="me"/>
# </head>
# <body class="allocine allocine__homepage logged-out" data-migration="incomplete" id="allocine__homepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main-ab1b33daf0.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
# Ex. :
# <a href="/film/fichefilm_gen_cfilm=242600.html">Un homme en colère</a>, <a href="/film/fichefilm_gen_cfilm=227548.html">West Side Story</a>, <a href="/series/ficheserie_gen_cserie=18145.html">Lucifer</a>, <a href="/series/ficheserie_gen_cserie=19475.html">The Resident</a> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"homepage"}' data-ga-trigger="clic" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon compte" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
# News
# </span></li><li class="header-nav-item"><a class="header-nav-link" href="/film/" title="Cinéma">
# Cinéma
# </a></li><li class="header-nav-item"><a class="header-nav-link" href="/series/" title="Séries">
# Séries
# </a></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Streaming">
# Streaming
# </span></li><li class="header-nav-item"><a class="header-nav-link" href="/trailer/" title="Trailers">
# Trailers
# </a></li><li class="header-nav-item"><a class="header-nav-link" href="/dvd/" title="DVD">
# DVD
# </a></li><li class="header-nav-item"><a class="header-nav-link" href="/vod/" title="VOD">
# VOD
# </a></li><li class="header-nav-item"><a class="header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-kids","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" href="/kids/" title="Kids">
# Kids
# </a></li><li class="header-nav-item"><span class="ACrL2RACrpc25leS8= header-nav-link-disney header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-disneyplus","eventLabel":"https:\/\/www.allocine.fr\/","eventAction":"navigation_menu_click","dimension81":"2022-05-10"}' data-ga-trigger="clic" title="Disney+"><i class="header-nav-logo-disney"></i>DISNEY<span class="disney-plus">+</span></span></li></ul><h1 class="header-main-subnav-holder"><div class="header-main-ephemeride">Découvrez notre recherche de <a href="/salle/">séances cinéma</a>, les <a href="/news/">news</a> et <a href="/dossiers/">dossiers</a> cinéma et séries TV, les <a href="/video/">émissions AlloCiné</a>, les <a href="/video/bandes-annonces/plus-recentes/">dernières bandes-annonces</a> et plus encore...</div></h1></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon compte" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"homepage"}' data-ga-trigger="clic"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
# Mon compte
# </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkY= button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout homepage-layout cf" id="content-layout">
# <div class="carousel carousel-main js-carousel" data-auto="true"><div class="carousel-row carousel-main-row"><figure class="carousel-item carousel-main-item current" data-emergence="1" data-ga='{"eventCategory":"emergence","eventLabel":"carousel","dimension82":"242492-jurassic_world_le_monde_d_apres","dimension84":"movie"}' data-index="1"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvdmlkZW8vcGxheWVyX2dlbl9jbWVkaWE9MTk1OTY1MDEmY2ZpbG09MjQyNDkyLmh0bWw= carousel-main-img-holder" data-ga='[{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"video\/player_gen_cmedia=19596501&amp;cfilm=242492.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":true,"dimension58":"Les h\u00e9ros de la saga Jurassic r\u00e9unis \u00e0 l\u2019\u00e9cran","dimension59":"moviepage"},{"eventCategory":"emergence","eventLabel":"carousel","dimension82":"242492-jurassic_world_le_monde_d_apres","dimension84":"movie"}]' data-ga-trigger="clic"><img class="carousel-main-image" height="400" src="https://fr.web.img4.acsta.net/img/17/b5/17b500d7d98a542b80e51db26c003c09.jpg" title="Les héros de la saga Jurassic réunis à l’écran" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvdmlkZW8vcGxheWVyX2dlbl9jbWVkaWE9MTk1OTY1MDEmY2ZpbG09MjQyNDkyLmh0bWw= title" data-ga='[{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"video\/player_gen_cmedia=19596501&amp;cfilm=242492.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":true,"dimension58":"Les h\u00e9ros de la saga Jurassic r\u00e9unis \u00e0 l\u2019\u00e9cran","dimension59":"moviepage"},{"eventCategory":"emergence","eventLabel":"carousel","dimension82":"242492-jurassic_world_le_monde_d_apres","dimension84":"movie"}]' data-ga-trigger="clic" title="Les héros de la saga Jurassic réunis à l’écran">Les héros de la saga Jurassic réunis à l’écran</span><div class="desc">Sam Neill, Jeff Goldblum et Laura Dern prêtent main-forte à Chris Pratt et Bryce Dallas Howard, le 8 juin au cinéma.</div></figcaption></figure><figure class="carousel-item carousel-main-item" data-emergence="1" data-ga='{"eventCategory":"emergence_svod","eventLabel":"carousel","dimension82":"28448-oussekine","dimension84":"series"}' data-index="2"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4NzA4MjA5Lmh0bWw= carousel-main-img-holder" data-ga='[{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18708209.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":true,"dimension58":"Une trag\u00e9die qui a marqu\u00e9 la soci\u00e9t\u00e9 fran\u00e7aise","dimension59":"editorial_content"},{"eventCategory":"emergence_svod","eventLabel":"carousel","dimension82":"28448-oussekine","dimension84":"series"}]' data-ga-trigger="clic"><img class="carousel-main-image" data-src="https://fr.web.img5.acsta.net/img/35/6e/356e61edb769fdf42035de39402d48af.jpg" height="400" src="..." title="Une tragédie qui a marqué la société française" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTE4NzA4MjA5Lmh0bWw= title" data-ga='[{"hitType":"event","eventAction":"homepage","eventCategory":"Carousel","eventLabel":"article\/fichearticle_gen_carticle=18708209.html","dimension34":null,"dimension35":null,"dimension36":null,"dimension37":null,"dimension39":null,"dimension41":"yes","dimension42":true,"dimension58":"Une trag\u00e9die qui a marqu\u00e9 la soci\u00e9t\u00e9 fran\u00e7aise","dimension59":"editorial_content"},{"eventCategory":"emergence_svod","eventLabel":"carousel","dimension82":"28448 ...
# <section class="section section-wrap">
# <div class="titlebar titlebar-top-border titlebar-page titlebar-page"><h2 class="titlebar-title titlebar-title-lg"><span class="ACrL2ZACrpbG0v titlebar-link">Cinéma</span></h2></div>
# <nav class="third-nav third-nav-hash js-third-nav">
# <a class="item" href="/film/agenda/">Agenda des sorties</a> <a class="item js-item-mq-medium" href="/film/enfants/aucinema/">Films pour enfants à l'affiche</a> <a class="item js-item-mq-medium" href="/film/meilleurs/">Meilleurs films</a> <a class="item js-item-mq-medium" href="/film/meilleurs/documentaires/">Meilleurs documentaires</a>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Afficher plus d'éléments" class="item-more-picto icon icon-plus js-trigger-third-nav-sub"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <a class="item" href="/film/avantpremieres/">Avant-premières</a> <a class="item" href="/boxoffice/france/">Box Office</a> <a class="item" href="/film/meilleurs/decennie-2010/annee-2019/">Meilleurs films 2019</a> <a class="item" href="/film/enfants/">Tous les films pour enfants</a> <a class="item" href="/films/">Tous les films</a> <span class="ACrL2ZACrlc3RpdmFscy8= item">Festivals</span> <span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= item">Court-métrages</span>
# </div>
# </div>
# </nav>
# <div class="search-theater cf js-search-theater-push" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}' role="search">
# <div class="js-search-location" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}' role="search">
# <form action="/salle/recherche/" autocomplete="off" class="form-holder theaters-form form form-localization" method="get">
# <fieldset class="form-field">
# <input class="form-text" id="showtimes_search_q" name="showtimes_search[q]" placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." required="required" type="text"/>
# <button aria-label="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." class="form-submit button button-md icon icon-search" title="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." type="submit"></button>
# </fieldset>
# </form>
# </div>
# </div>
# </section>
# <section class="section section-wrap">
# <div class="gd gd-gap-20 gd-xs-12">
# <div class="gd-span-s-12 gd-span-l-1-8 gd-item-mw-0">
# <div class="mdl-inside">
# <div class="titlebar titlebar-arrow"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/film/sorties-semaine/">Sorties de la semaine</a></h3></div>
# <div class="roller-holder js-roller roller-arrow-title roller-hp" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI1MTM5MC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MTU0JmNmaWxtPTI1MTM5MC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNTEzOTAuaHRtbA== thumbnail-container thumbnail-link" title="Doctor Strange in the Multiverse of Madness"><img alt="Doctor Strange in the Multiverse of Madness" class="thumbnail-img" height="200" src="https://fr.web.img6.acsta.net/c_150_200/pictures/22/04/08/10/30/1779137.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=251390.html" title="Doctor Strange in the Multiverse of Madness">Doctor Strange in the Multiverse of Madness</a><div class="meta-description light">
# De Sam Raimi
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5MzI3Mi8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MDc2JmNmaWxtPTI5MzI3Mi5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTMyNzIuaHRtbA== thumbnail-container thumbnail-link" title="Ténor"><img alt="Ténor" class="thumbnail-img" height="200" src="https://fr.web.img2.acsta.net/c_150_200/pictures/22/03/21/14/50/4272885.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=293272.html" title="Ténor">Ténor</a><div class="meta-description light">
# De Claude Zidi Jr.
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4NDY3Ni8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MjQyJmNmaWxtPTI4NDY3Ni5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODQ2NzYuaHRtbA== thumbnail-container thumbnail-link" title="Les Passagers de la nuit"><img alt="Les Passagers de la nuit" class="thumbnail-img" height="200" src="https://fr.web.img3.acsta.net/c_150_200/pictures/22/04/12/16/01/3361793.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=284676.html" title="Les Passagers de la nuit">Les Passagers de la nuit</a><div class="meta-description light">
# De Mikhaël Hers
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5MjkyOC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MjEzJmNmaWxtPTI5MjkyOC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTI5MjguaHRtbA== thumbnail-container thumbnail-link" title="Le Roi cerf"><img alt="Le Roi cerf" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/22/04/01/11/41/2925578.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=292928.html" title="Le Roi cerf">Le Roi cerf</a><div class="meta-description light">
# De Masashi Ando, Masayuki Miyaji
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4NDY3OC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MTgzJmNmaWxtPTI4NDY3OC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODQ2NzguaHRtbA== thumbnail-container thumbnail-link" title="Varsovie 83, une affaire d'État"><img alt="Varsovie 83, une affaire d'État" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/pictures/22/03/30/08/49/2889359.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=284678.html" title="Varsovie 83, une affaire d'État">Varsovie 83, une affaire d'État</a><div class="meta-description light">
# De Jan P. Matuszynski
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMwMzE5MC8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMDMxOTAuaHRtbA== thumbnail-container thumbnail-link" title="Soirée IMA, film et showcase"><img alt="Soirée IMA, film et showcase" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_150_200/pictures/22/03/30/11/29/3291572.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=303190.html" title="Soirée IMA, film et showcase">Soirée IMA, film et showcase</a><div class="meta-description light">
# De Nils Tavernier
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI3OTY5Ny8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MjgwJmNmaWxtPTI3OTY5Ny5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzk2OTcuaHRtbA== thumbnail-container thumbnail-link" title="Petite leçon d’amour"><img alt="Petite leçon d’amour" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/22/04/08/11/02/5856209.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=279697.html" title="Petite leçon d’amour">Petite leçon d’amour</a><div class="meta-description light">
# De Eve Deboise
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4NTQ4OC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk0OTIxJmNmaWxtPTI4NTQ4OC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODU0ODguaHRtbA== thumbnail-container thumbnail-link" title="Miss Marx"><img alt="Miss Marx" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/pictures/22/02/21/11/45/2639264.png" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=285488.html" title="Miss Marx">Miss Marx</a><div class="meta-description light">
# De Susanna Nicchiarelli
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5MzA5OC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MjE2JmNmaWxtPTI5MzA5OC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTMwOTguaHRtbA== thumbnail-container thumbnail-link" title="Il buco"><img alt="Il buco" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_150_200/pictures/22/04/01/16/37/0325754.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=293098.html" title="Il buco">Il buco</a><div class="meta-description light">
# De Michelangelo Frammartino
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4Mzc0Ni8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkxNzY2JmNmaWxtPTI4Mzc0Ni5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODM3NDYuaHRtbA== thumbnail-container thumbnail-link" title="Limbo"><img alt="Limbo" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/22/03/15/15/17/1725453.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=283746.html" title="Limbo">Limbo</a><div class="meta-description light">
# De Ben Sharrock
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5Mzc3NC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MTczJmNmaWxtPTI5Mzc3NC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTM3NzQuaHRtbA== thumbnail-container thumbnail-link" title="L'Été l’éternité"><img alt="L'Été l’éternité" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/pictures/22/02/02/09/24/0832063.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTM3NzQuaHRtbA== meta-title meta-title-link" title="L'Été l’éternité">L'Été l’éternité</span><div class="meta-description light">
# De Émilie Aussel
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4MjI2Ni8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1ODYwJmNmaWxtPTI4MjI2Ni5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODIyNjYuaHRtbA== thumbnail-container thumbnail-link" title="Detroiters"><img alt="Detroiters" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/pictures/22/04/11/11/13/4656601.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODIyNjYuaHRtbA== meta-title meta-title-link" title="Detroiters">Detroiters</span><div class="meta-description light">
# De Andreï Schtakleff
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5NDc2Ny8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTkzODg1JmNmaWxtPTI5NDc2Ny5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTQ3NjcuaHRtbA== thumbnail-container thumbnail-link" title="Anatomy of Time"><img alt="Anatomy of Time" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_150_200/pictures/21/09/14/17/47/3069566.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTQ3NjcuaHRtbA== meta-title meta-title-link" title="Anatomy of Time">Anatomy of Time</span><div class="meta-description light">
# De Jakrawal Nilthamrong
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI2ODEyNC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MjAwJmNmaWxtPTI2ODEyNC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNjgxMjQuaHRtbA== thumbnail-container thumbnail-link" title="Los Fuertes"><img alt="Los Fuertes" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/pictures/22/03/21/12/39/0301537.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNjgxMjQuaHRtbA== meta-title meta-title-link" title="Los Fuertes">Los Fuertes</span><div class="meta-description light">
# De Omar Zúñiga Hidalgo
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5MjUzMC8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTI1MzAuaHRtbA== thumbnail-container thumbnail-link" title="Pissarro : père de l’impressionnisme"><img alt="Pissarro : père de l’impressionnisme" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_150_200/pictures/21/12/10/12/51/0740413.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTI1MzAuaHRtbA== meta-title meta-title-link" title="Pissarro : père de l’impressionnisme">Pissarro : père de l’impressionnisme</span><div class="meta-description light">
# De David Bickerstaff
# </div></div></div></div></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div>
# <span class="ACrL2ZACrpbG0vc29ydGllcy1zZW1haW5lLw== end-section-link" title="Toutes les sorties de la semaine">Toutes les sorties de la semaine</span>
# </div>
# <div class="mdl-outside">
# <div class="titlebar titlebar-arrow"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv titlebar-link">Toujours à l'affiche</span></h3></div>
# <div class="roller-holder js-roller roller-arrow-title roller-hp" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTIyODA4Ny8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1ODI3JmNmaWxtPTIyODA4Ny5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yMjgwODcuaHRtbA== thumbnail-container thumbnail-link" title="Les Animaux Fantastiques : les Secrets de Dumbledore"><img alt="Les Animaux Fantastiques : les Secrets de Dumbledore" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_150_200/pictures/22/03/16/15/20/0170262.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=228087.html" title="Les Animaux Fantastiques : les Secrets de Dumbledore">Les Animaux Fantastiques : les Secrets de Dumbledore</a><div class="meta-description light">
# De David Yates
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI3OTY2NC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1Njk4JmNmaWxtPTI3OTY2NC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzk2NjQuaHRtbA== thumbnail-container thumbnail-link" title="Downton Abbey II : Une nouvelle ère"><img alt="Downton Abbey II : Une nouvelle ère" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/pictures/22/02/15/09/10/5252741.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=279664.html" title="Downton Abbey II : Une nouvelle ère">Downton Abbey II : Une nouvelle ère</a><div class="meta-description light">
# De Simon Curtis
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI3NDQ4NC8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MDI0JmNmaWxtPTI3NDQ4NC5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzQ0ODQuaHRtbA== thumbnail-container thumbnail-link" title="Qu'est-ce qu'on a tous fait au Bon Dieu ?"><img alt="Qu'est-ce qu'on a tous fait au Bon Dieu ?" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/pictures/21/10/21/10/17/5465951.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=274484.html" title="Qu'est-ce qu'on a tous fait au Bon Dieu ?">Qu'est-ce qu'on a tous fait au Bon Dieu ?</a><div class="meta-description light">
# De Philippe de Chauveron
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4NzA4Mi8= layer-link">Séances</span><span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MDk0JmNmaWxtPTI4NzA4Mi5odG1s layer-link">Bande-annonce</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODcwODIuaHRtbA== thumbnail-container thumbnail-link" title="Le Secret de la cité perdue"><img alt="Le Secret de la cité perdue" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_150_200/pictures/22/02/22/12/00/1445602.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=287082.html" title="Le Secret de la cité perdue">Le Secret de la cité perdue</a><div class="meta-description light">
# De Aaron Nee, Adam Nee
# </div></div></div></div></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div>
# <a class="end-section-link" href="/film/aucinema/" title="Tous les films encore à l'affiche">Tous les films encore à l'affiche</a>
# </div>
# <div class="hp-visuel-wrapper">
# <span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvc3BlZWRub3Rlci9jdWx0LW1vdmllcy8=" data-ga='{"eventCategory":"entities_list","eventAction":"clic","eventLabel":"banner_hp"}' data-ga-trigger="clic">
# <img alt="Notez des films" class="hp-visuel" data-src="https://fr.web.img6.acsta.net/commons/v9/allocine/visuel-hp/visuel-speednoter.png" height="220" src="..." width="664"/>
# </span>
# </div>
# </div>
# <div class="gd-span-s-12 gd-span-l-9-4">
# <div id="mobile-referrer-atf"></div>
# <div class="movie-next">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv titlebar-link">Prochainement</span></h3><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Classement des films les plus consultés hier</span></div></div>
# <ul class="list-entity list-movie-hp small-crop mdl-fixed">
# <li class="list-entity-item list-entity-item-first cf">
# <figure class="thumbnail">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2NTAxJmNmaWxtPTI0MjQ5Mi5odG1s thumbnail-container thumbnail-link" title="Jurassic World: Le Monde d'après">
# <img alt="Jurassic World: Le Monde d'après" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_120_160/pictures/22/04/14/18/30/0040092.jpg" height="160" src="..." width="120"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=242492.html"> Jurassic World: Le Monde d'après </a>
# <div class="list-entity-item-director">8 juin 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19596501&amp;cfilm=242492.html"> </a>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=178014.html"> Avatar : la voie de l'eau</a>
# <div class="list-entity-item-director">14 décembre 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19596589&amp;cfilm=178014.html"> </a>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=293005.html"> Utama : La Terre Oubliée</a>
# <div class="list-entity-item-director">11 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19596349&amp;cfilm=293005.html"> </a>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=284745.html"> On sourit pour la photo</a>
# <div class="list-entity-item-director">11 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19596144&amp;cfilm=284745.html"> </a>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=255880.html"> Firestarter</a>
# <div class="list-entity-item-director">1 juin 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <a aria-label="Lire" class="icon icon-play-mini" href="/video/player_gen_cmedia=19595632&amp;cfilm=255880.html"> </a>
# </li>
# <li class="more-trigger js-more-trigger">Voir plus de films</li>
# <li class="row more-hidden">
# <ul>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzgxODIuaHRtbA== list-entity-item-link"> The Northman</span>
# <div class="list-entity-item-director">11 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MTIyJmNmaWxtPTI3ODE4Mi5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xODY2MzYuaHRtbA== list-entity-item-link"> Top Gun: Maverick</span>
# <div class="list-entity-item-director">25 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTg3MDQyJmNmaWxtPTE4NjYzNi5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMDEwMTEuaHRtbA== list-entity-item-link"> Ima</span>
# <div class="list-entity-item-director">11 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MTg0JmNmaWxtPTMwMTAxMS5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODg5MjUuaHRtbA== list-entity-item-link"> Les Folies fermières</span>
# <div class="list-entity-item-director">11 mai 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MTU4JmNmaWxtPTI4ODkyNS5odG1s icon icon-play-mini"> </span>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzUyMDcuaHRtbA== list-entity-item-link"> Thor: Love And Thunder</span>
# <div class="list-entity-item-director">13 juillet 2022</div>
# </div>
# <div class="label-wrapper">
# <div class="label label-soon label-soon-theater">En salle</div>
# </div>
# <span aria-label="Lire" class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk2MzgyJmNmaWxtPTI3NTIwNy5odG1s icon icon-play-mini"> </span>
# </li>
# </ul>
# </li>
# </ul>
# <a class="end-section-link" href="/film/attendus/" title="Tous les films à venir">Tous les films à venir</a>
# </div>
# </div>
# </div>
# </section>
# <section class="section section-wrap">
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/news/cinema/">Dernières news cinéma</a></h3></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-m-3">
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Batman : Avec le Joker,  Jack Nicholson voulait faire peur aux enfants" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/22/05/09/16/49/1418509.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Culture ciné</div><div class="meta-date">mardi 10 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709578.html">Batman : Avec le Joker, Jack Nicholson voulait faire peur aux enfants</a></div></div></div>
# ...
# </div>
# </div>
# </div>
# </div>
# <div class="main-footer-bottom">
# <p class="info">
# <span class="ACrL3NACrlcnZpY2UvY29udGFjdC8=">Contact</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvYXByb3Bvcy8=">Qui sommes-nous</span> <span class="pipe">|</span>
# <span class="ACraHRACr0cDovL3d3dy53ZWJlZGlhLmZy" rel="noopener" target="_blank"> Recrutement</span> <span class="pipe">|</span>
# <span class="ACraHRACr0cDovL3NwZWNzLndlYmVkaWEuZnI=" rel="noopener" target="_blank">Publicité</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29uZGl0aW9ucy5odG1s">CGU</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29va2llcy5odG1s">Politique de cookies</span> <span class="pipe">|</span>
# <a class="cookie-notice" href="#">Préférences cookies</a> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY2hhcnRlLmh0bWw=">Données Personnelles</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uvbm90ZS1wcmVzc2UuaHRtbA==">Revue de presse</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uv">Les services AlloCiné</span> <span class="pipe">|</span>
# ©AlloCiné
# </p>
# <p class="info">
# Retrouvez tous les horaires et infos de votre cinéma sur le numéro AlloCiné : <span class="phone">0 892 892 892</span> (0,90€/minute)
# </p>
# <p class="info-logo">
# <i class="sp footer-logo"></i>
# <i class="sp footer-logo-boxoffice"></i>
# </p>
# </div>
# </footer>
# <div class="mq-state" id="mq-state"></div>
# <div class="message-board">
# <div class="js-message-board"></div>
# </div>
# <a aria-label="Retour en haut de la page" class="back-top icon icon-arrow-top" href="#allocine__homepage" id="back-top">
# <span class="no-icon">Back to Top</span>
# </a>
# <div class="easyAdsBox"> </div>
# <div id="modal-anchors-container">
# </div>
# <script type="text/javascript">
#     window.didomiOnReady = window.didomiOnReady || [];
#     window.didomiEventListeners = window.didomiEventListeners || [];
# </script>
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target=TtwHt2xD";t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('e23a01f6-a508-4e71-8f50-c1a9cae7c0d0')})();</script>
# <script type="text/javascript">
#             var dataLayerGA = {"dimension10":"homepage"};
#         </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/120157152","account-first-level":"\/ALLOCINE_FR_WEB","tag-id":"\/120157152\/ALLOCINE_FR_WEB","tag-other-levels":"\/homepage\/home","navEgg":null,"targeting":{"site":"allocine","site_route":"homepage","site_section":"home","environment":"web","video_id":"19596501","video_movie_id":"242492","video_movie_genre":["13025","13001","13021"],"video_movie_distributors":"15897","is_for_kids":"0"},"autoRefresh":true,"cmpPaywall":{"name":"didomi","siteId":"e23a01f6-a508-4e71-8f50-c1a9cae7c0d0","noticeId":"TtwHt2xD","paywall":{"clientId":"AVvF60FpOZcS6UoBe6sf8isBLYwzuLgMQCnNdE-FvpoW_OhR8P6zERqhyuIBGPOxqrTHKxv7QxsXnfck","planId":"P-66F73522PX986223DMBQZG5A","tosUrl":"\/service\/cgv.html","touUrl":"\/service\/conditions.html","privacyUrl":"\/service\/charte.html"},"includeCmp":false},"customInterstitialCapping":1,"adsMapping":{"interstitial":"dfp-interstitial","header":"dfp-masthead","inread1":"dfp-inread","rectangle_atf":"dfp-atf","rectangle_mtf":"dfp-mtf","rectangle_btf":"dfp-btf","rectangle_mtf_2":"dfp-autopromo","rectangle_atf_diapo":"dfp-slideshow","slideshow_native_banner":"dfp-slideshownativebanner","imagead":"dfp-imagead","header_link":"dfp-headerlink","footer":"dfp-footer","pulse":"dfp-pulse","native_banner":"dfp-nativebanner","native_banner_ope":"dfp-nativebanner-ope","native_button":"dfp-nativebutton","native_rectangle":"dfp-nativerectangle","native_VOD":"dfp-nativevod","inread_added":"dfp-added-ad"}};
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-atf","dfp-pulse"];
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"cc2b8ddf7a8e8801f75337020920fec3c72a477b","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min-755b0d7e3c.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min-760736ff24.css"},"images":{"logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine-7e88ee87c5.svg","bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson-e492ec8e56.gif","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously-ffccba6479.gif","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle-5d973cbbc2.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found-dec1f46fbc.gif","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster-7c731e1347.png","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles-766780d2bf.png","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding-a32c4541a1.png","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions-0009180ea0.png","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron-363298eee7.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":"wads","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-PL6PBF","analyticsUACode":"UA-597605-13","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"allocine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbnD0xyjS6fqSR","ssoButton":"https:\/\/fr.web.img1.acsta.net\/commons\ ...
#     AC.routing = {"base_url":"","routes":{"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_migration":"deno","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["variable","-","\\d+","localization",true],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","day":0,"_brand":"allocine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["text","\/favoris\/seances"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","day":0,"_brand":"allocine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia",true],["text","\/video\/player_gen_cmedia"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_migration":"deno","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/videos\/fichefilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::allVideosTrailer ...
#     AC.route = 'homepage';
# }(window));
# </script>
# <script src="https://assets.allocine.fr/js/website/translations-b711c990e5af597dbe10279815cd0a52.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.93bf89cf686ddeb87612.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/home.c86c9eb7a778c163256a.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"home","site_section":"other"}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = [];
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min\u002D19a7f529a7.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# </html>

# %% [markdown]
# On your web browser (Chrome, Firefox,...), you can use the "inspect" function (right click -> inspect) and drag your mouse to the areas of the page that interest you. At the same time you will see the part of the HTML script highlighted that corresponds to the area that interests you.
#
# That's how you find the tags that you are interested in.

# %% [markdown]
# I notice that the relative link of the web page specific to the new movie on the poster is stored in these tags:
#
# ```html
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=235582.html" title="Le Grand Bain">Le Grand Bain</a>
# ```

# %%
for p in soup.find_all("a"):
    print(p.text)
# Out:
# Un homme en colère
# West Side Story
# Lucifer
# The Resident
#
# Cinéma
#
#
# Séries
#
#
# Trailers
#
#
# DVD
#
#
# VOD
#
#
# Kids
#
# séances cinéma
# news
# dossiers
# émissions AlloCiné
# dernières bandes-annonces
# Agenda des sorties
# Films pour enfants à l'affiche
# Meilleurs films
# Meilleurs documentaires
# Avant-premières
# Box Office
# Meilleurs films 2019
# Tous les films pour enfants
# Tous les films
# Sorties de la semaine
# Doctor Strange in the Multiverse of Madness
# Ténor
# Les Passagers de la nuit
# Le Roi cerf
# Varsovie 83, une affaire d'État
# Soirée IMA, film et showcase
# Petite leçon d’amour
# Miss Marx
# Il buco
# Limbo
# Les Animaux Fantastiques : les Secrets de Dumbledore
# Downton Abbey II : Une nouvelle ère
# Qu'est-ce qu'on a tous fait au Bon Dieu ?
# Le Secret de la cité perdue
# Tous les films encore à l'affiche
#  Jurassic World: Le Monde d'après
#
#  Avatar : la voie de l'eau
#
#  Utama : La Terre Oubliée
#
#  On sourit pour la photo
#
#  Firestarter
#
# Tous les films à venir
# Dernières news cinéma
# Batman : Avec le Joker, Jack Nicholson voulait faire peur aux enfants
# TV Tips : quand Capitaine Kirk jouait les espions
# Pilote sur OCS : c’est quoi ce thriller militaire avec Hugo Becker ?
# Jurassic World 3 : les dinosaures se déchaînent sur les images spectaculaires de la bande-annonce finale
# Doctor Strange 2 : qui est Sam Raimi, le réalisateur du film Marvel et légende du cinéma d'horreur ?
# Quiz Cinéma : trouvez l'intrus parmi ces stars ! (attention, c'est pas facile...)
# Tous les dossiers cinéma
# Bandes-annonces à ne pas manquer
# 365 jours : Au lendemain Bande-annonce VO
# Dans les yeux de Thomas Pesquet et autres aventures spatiales Bande-annonce VF
# Disney+
# Netflix
# Amazon Prime Video
# Canal+
# Oussekine sur Disney+ : on a vu le premier épisode de cette série renversante qui va marquer 2022
# Heat, Le Parrain 2e partie… : Robert De Niro en 3 rôles de gangster sur Prime Video
# We Own This City sur OCS : la suite de The Wire ?
# Les 203 épisodes de cette série culte des années 90 sont enfin disponibles gratuitement en streaming !
# Séries à voir  sur CANAL+
# Halo
# Infiniti
# Pourquoi pas Evans ?
# La Flamme
# OVNI(s)
# Meilleures séries  sur Netflix
# Arcane
# Breaking Bad
# Notre planète
# Peaky Blinders
# L'Attaque des Titans
# Films disponibles  sur Disney+
# Doctor Strange
# Alerte rouge
# Avengers: Endgame
# Avengers: Infinity War
# Titanic
# Films disponibles sur Prime Video
# Le Couteau par la lame
# The Contractor
# Eaux profondes
# Avant toi
# Gold
# Les derniers films en VOD
# En Attendant Bojangles
# The King's Man : Première Mission
# La Place d’une autre
# Les dernières séries en VOD
# Les Enquêtes de Murdoch
# HPI
# La Faute à Rousseau
# Sorties DVD & Blu-Ray
# La Cité pétrifiée
# Le Rayon invisible
# Alerte la nuit
# Meilleures séries
# Episodes inédits ce soir à la TV
# Séries tv inédites à voir
# Nouvelles saisons attendues
# Toutes les séries
# Dernières vidéos de séries
# Episodes inédits à la TV demain
# Toutes les vidéos de séries
# Tous les teasers de séries
# Top séries de la semaine
# Les 7 vies de Léa
# En un battement
# Moon Knight
# Les séries les plus attendues
# Le Flambeau, les aventuriers de Chupacabra
# Visions
# Star Wars: Obi-Wan Kenobi
# Game Of Thrones: House of the Dragon
# L'actu séries
# Visitors sur Warner TV : comment Simon Astier a voulu créer "un monde qui n'existe pas"
# Un Si Grand Soleil : pourquoi Hélène a-t-elle drogué Claire ?
# Plus belle la vie en avance : résumé de l'épisode du mardi 10 mai 2022 [SPOILERS]
# Demain nous appartient : ce qui vous attend dans l'épisode 1182 du mardi 10 mai 2022 [SPOILERS]
# Fun Facts
# Faux raccord
# Fanzone
# Aviez-vous remarqué ?
# Give Me Five
# The Big Fan Theory
# AlloCiné Zap
# AlloCiné Séries
# Top 5
# Ma scène préférée
# Stars
# Toutes les stars françaises
# Toutes les stars américaines
# Top stars complet
# Bandes originales
# Musique de films
# Musique de séries TV
# News jeux vidéo
# Filmstarts
# Beyazperde
# SensaCine España
# SensaCine México
# Adorocinema
# Préférences cookies
#
# Back to Top

# %% [markdown]
# This time, the site is more difficult to "extract". Let's use much more specific parameters to the search function `find_all`.

# %%
# In addition to the tag `a`, which is easily identifiable, we notice some additional
# information such as the value of the class variable of these identical tags.
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    print(elem)
# Out:
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=251390.html" title="Doctor Strange in the Multiverse of Madness">Doctor Strange in the Multiverse of Madness</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=293272.html" title="Ténor">Ténor</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=284676.html" title="Les Passagers de la nuit">Les Passagers de la nuit</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=292928.html" title="Le Roi cerf">Le Roi cerf</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=284678.html" title="Varsovie 83, une affaire d'État">Varsovie 83, une affaire d'État</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=303190.html" title="Soirée IMA, film et showcase">Soirée IMA, film et showcase</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=279697.html" title="Petite leçon d’amour">Petite leçon d’amour</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=285488.html" title="Miss Marx">Miss Marx</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=293098.html" title="Il buco">Il buco</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=283746.html" title="Limbo">Limbo</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=228087.html" title="Les Animaux Fantastiques : les Secrets de Dumbledore">Les Animaux Fantastiques : les Secrets de Dumbledore</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=279664.html" title="Downton Abbey II : Une nouvelle ère">Downton Abbey II : Une nouvelle ère</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=274484.html" title="Qu'est-ce qu'on a tous fait au Bon Dieu ?">Qu'est-ce qu'on a tous fait au Bon Dieu ?</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=287082.html" title="Le Secret de la cité perdue">Le Secret de la cité perdue</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=28872.html" title="Les 7 vies de Léa">Les 7 vies de Léa</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=31219.html" title="En un battement">En un battement</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=25546.html" title="Moon Knight">Moon Knight</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=31595.html" title="Le Flambeau, les aventuriers de Chupacabra">Le Flambeau, les aventuriers de Chupacabra</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=29175.html" title="Visions">Visions</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=25501.html" title="Star Wars: Obi-Wan Kenobi">Star Wars: Obi-Wan Kenobi</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=25633.html" title="Game Of Thrones: House of the Dragon">Game Of Thrones: House of the Dragon</a>

# %% [markdown]
# #### Recovery of `href`

# %% [markdown]
# We have noticed the presence of `href` links to the pages that interest us. Let's go get them back:

# %%
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    print(elem.get("href"))
# Out:
# /film/fichefilm_gen_cfilm=251390.html
# /film/fichefilm_gen_cfilm=293272.html
# /film/fichefilm_gen_cfilm=284676.html
# /film/fichefilm_gen_cfilm=292928.html
# /film/fichefilm_gen_cfilm=284678.html
# /film/fichefilm_gen_cfilm=303190.html
# /film/fichefilm_gen_cfilm=279697.html
# /film/fichefilm_gen_cfilm=285488.html
# /film/fichefilm_gen_cfilm=293098.html
# /film/fichefilm_gen_cfilm=283746.html
# /film/fichefilm_gen_cfilm=228087.html
# /film/fichefilm_gen_cfilm=279664.html
# /film/fichefilm_gen_cfilm=274484.html
# /film/fichefilm_gen_cfilm=287082.html
# /series/ficheserie_gen_cserie=28872.html
# /series/ficheserie_gen_cserie=31219.html
# /series/ficheserie_gen_cserie=25546.html
# /series/ficheserie_gen_cserie=31595.html
# /series/ficheserie_gen_cserie=29175.html
# /series/ficheserie_gen_cserie=25501.html
# /series/ficheserie_gen_cserie=25633.html

# %% [markdown]
# Can you retrieve the titles for me by searching for `"title"` in the items of the previous list?

# %%
for elem in soup.find_all("a",attrs={"class": "meta-title meta-title-link"}):
    print(elem.get("title"))
# Out:
# Doctor Strange in the Multiverse of Madness
# Ténor
# Les Passagers de la nuit
# Le Roi cerf
# Varsovie 83, une affaire d'État
# Soirée IMA, film et showcase
# Petite leçon d’amour
# Miss Marx
# Il buco
# Limbo
# Les Animaux Fantastiques : les Secrets de Dumbledore
# Downton Abbey II : Une nouvelle ère
# Qu'est-ce qu'on a tous fait au Bon Dieu ?
# Le Secret de la cité perdue
# Les 7 vies de Léa
# En un battement
# Moon Knight
# Le Flambeau, les aventuriers de Chupacabra
# Visions
# Star Wars: Obi-Wan Kenobi
# Game Of Thrones: House of the Dragon

# %% [markdown]
# #### Get summary

# %% [markdown]
# Let's start by building the URL that we will use to retrieve the summaries.
#
# Start by putting the `href` values in a list of links.

# %%
links = []
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    links.append(elem.get("href"))
links
# Out:
# ['/film/fichefilm_gen_cfilm=251390.html',
#  '/film/fichefilm_gen_cfilm=293272.html',
#  '/film/fichefilm_gen_cfilm=284676.html',
#  '/film/fichefilm_gen_cfilm=292928.html',
#  '/film/fichefilm_gen_cfilm=284678.html',
#  '/film/fichefilm_gen_cfilm=303190.html',
#  '/film/fichefilm_gen_cfilm=279697.html',
#  '/film/fichefilm_gen_cfilm=285488.html',
#  '/film/fichefilm_gen_cfilm=293098.html',
#  '/film/fichefilm_gen_cfilm=283746.html',
#  '/film/fichefilm_gen_cfilm=228087.html',
#  '/film/fichefilm_gen_cfilm=279664.html',
#  '/film/fichefilm_gen_cfilm=274484.html',
#  '/film/fichefilm_gen_cfilm=287082.html',
#  '/series/ficheserie_gen_cserie=28872.html',
#  '/series/ficheserie_gen_cserie=31219.html',
#  '/series/ficheserie_gen_cserie=25546.html',
#  '/series/ficheserie_gen_cserie=31595.html',
#  '/series/ficheserie_gen_cserie=29175.html',
#  '/series/ficheserie_gen_cserie=25501.html',
#  '/series/ficheserie_gen_cserie=25633.html']

# %% [markdown]
# The absolute URL of the movie pages we are looking for are built in this form: http://www.allocine.fr/film/fichefilm_gen_cfilm=243835.html
#
# It is therefore necessary to take the previous list and build the absolute URLs for our search
# It's up to you to play.
#
# NB: Do not take the links for the shows(series). We only want movies.

# %%
movie_links = ["http://www.allocine.fr" + elem for elem in links if "film" in elem]
movie_links
# Out:
# ['http://www.allocine.fr/film/fichefilm_gen_cfilm=251390.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=293272.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=284676.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=292928.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=284678.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=303190.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=279697.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=285488.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=293098.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=283746.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=228087.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=279664.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=274484.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=287082.html']

# %% [markdown]
# Finally, on each page, the title and synopsis must be retrieved. Let's try for a movie, the first of the list.

# %%
url = movie_links[0]
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content, "lxml")
soup
# Out:
# http://www.allocine.fr/film/fichefilm_gen_cfilm=251390.html 200
# <!DOCTYPE html>
# <html lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="index,follow,max-snippet:-1,max-image-preview:standard" name="robots"/>
# <title>Doctor Strange in the Multiverse of Madness - film 2022 - AlloCiné</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="AlloCine" name="author"/>
# <meta content="France" name="country"/>
# <meta content="48.87078;2.30447" name="geo.position"/>
# <meta content="FR" name="geo.country"/>
# <meta content="48.87078;2.30447" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="Doctor Strange in the Multiverse of Madness est un film réalisé par Sam Raimi avec Benedict Cumberbatch, Elizabeth Olsen. Synopsis : Dans ce nouveau film Marvel Studios, l’univers cinématographique Marvel déverrouille et repousse les limites du multivers encore plus loin. Voyagez dans l’inconnu avec Doctor Stran" name="description"/>
# <meta content="AlloCiné" property="og:site_name"/>
# <meta content="Doctor Strange in the Multiverse of Madness" property="og:title"/>
# <meta content="Dans ce nouveau film Marvel Studios, l’univers cinématographique Marvel déverrouille et repousse les limites du multivers encore plus loin. Voyagez dans l’inconnu avec Doctor Strange, qui avec l’aide d’anciens et de nouveaux alliés mystiques, travers" property="og:description"/>
# <meta content="https://fr.web.img5.acsta.net/pictures/22/04/08/10/30/1779137.jpg" property="og:image"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="99197768694" property="fb:app_id"/>
# <meta content="Sam Raimi" property="video:director"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="@allocine" name="twitter:site"/>
# <meta content="Doctor Strange in the Multiverse of Madness" name="twitter:title"/>
# <meta content="Dans ce nouveau film Marvel Studios, l’univers cinématographique Marvel déverrouille et repousse les limites du multivers encore plus loin. Voyagez dans l’inconnu avec Doctor Strange, qui avec l’aide d’anciens et de nouveaux alliés mystiques, travers" name="twitter:description"/>
# <meta content="https://fr.web.img5.acsta.net/pictures/22/04/08/10/30/1779137.jpg" name="twitter:image"/>
# <meta content="allocine" name="twitter:app:name:iphone"/>
# <meta content="allocine" name="twitter:app:name:ipad"/>
# <meta content="allocine" name="twitter:app:name:googleplay"/>
# <meta content="allocine://open/movie?code=251390" name="twitter:app:url:iphone"/>
# <meta content="allocine://open/movie?code=251390" name="twitter:app:url:ipad"/>
# <meta content="allocine://open/movie?code=251390" name="twitter:app:url:googleplay"/>
# <meta content="351184863" name="twitter:app:id:iphone"/>
# <meta content="351184863" name="twitter:app:id:ipad"/>
# <meta content="com.allocine.androidapp" name="twitter:app:id:googleplay"/>
# <meta content="app-id=351184863, app-argument=allocine://open/movie?code=251390" name="apple-itunes-app"/>
# <meta content="107276450147" property="fb:pages"/>
# <link href="https://assets.allocine.fr" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.allocine.fr/skin/font/icon/font-icon-9f5f785d6d.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey-5de8867c13.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.allocine.fr/js/website/website-common.93bf89cf686ddeb87612.js" rel="preload"/>
# <link as="script" href="https://assets.allocine.fr/js/website/moviepage.9db4c2f6dc1663fc8d35.js" rel="preload"/>
# <link href="https://sdk.privacy-center.org/" rel="preconnect"/>
# <link as="image" href="https://fr.web.img3.acsta.net/c_310_420/pictures/22/04/08/10/30/1779137.jpg" rel="preload"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\00201c" "\00201d" "\002018" "\002019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.icon:after,.icon:before,.more-trigger:after,.rating-star:before{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}@font-face{font-family:font-icon;src:url(https://assets.allocine.fr/skin/font/icon/font-icon-9f5f785d6d.woff2) format("woff2"),url(https://assets.allocine.fr/skin/font/icon/font-icon-892c1815af.woff) format("woff"),url(https://assets.allocine.fr/skin/font/icon/font-icon-7e32a67362.ttf) format("truetype");font-weight:400;font-style:normal}.footer-logo-WB{background-position:-284px 0;width:112px;height:29px}.footer-logo-boxoffice{background-position:-925px 0;width:315px;height:26px}.footer-logo{background-position:-398px 0;width:120px;height:34px}.header-arrow--bottom--black{background-position:0 0;width:16px;height:16px}.header-back{background-position:-92px 0;width:46px;height:46px}.header-burger{background-position:-140px 0;width:46px;height:46px}.header-home{background-position:-18px 0;width:16px;height:16px}.header-logo--primary{background-position:-661px 0;width:262px;height:74px}.header-logo-userspace{background-position:-520px 0;width:139px;height:39px}.header-minify{background-position:-188px 0;width:46px;height:46px}.header-music{background-position:-36px 0;width:16px;height:16px}.header-netfli ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'allocine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min\u002D760736ff24.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.allocine.fr/apple-touch-icon/allocine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/allocine" rel="me"/>
# </head>
# <body class="allocine allocine__moviepage logged-out" data-migration="deno" id="allocine__moviepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main-ab1b33daf0.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
# Ex. :
# <a href="/film/fichefilm_gen_cfilm=133392.html">Dune</a>, <a href="/film/fichefilm_gen_cfilm=212358.html">James Bond 25</a>, <a href="/film/fichefilm_gen_cfilm=224395.html">Cruella</a> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"moviepage"}' data-ga-trigger="clic" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon compte" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
# News
# </span></li><li class="header-nav-item is-active"><span class="ACrL2ZACrpbG0v header-nav-link current" title="Cinéma">
# Cinéma
# </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vbWVpbGxldXJzLw== header-nav-link" title="Meilleurs films">
# Meilleurs films
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv header-nav-link" title="Films à l'affiche">
# Films à l'affiche
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv header-nav-link" title="Prochainement">
# Prochainement
# </span></li><li class="header-subnav-item"><span class="ACrL3NACrhbGxlLw== header-nav-link" title="Séances">
# Séances
# </span></li><li class="header-subnav-item"><span class="ACrL2JACrveG9mZmljZS9mcmFuY2Uv header-nav-link" title="Box Office">
# Box Office
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= header-nav-link" title="Courts-métrages">
# Courts-métrages
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG1zLw== header-nav-link" title="Tous les films">
# Tous les films
# </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL3NACrlcmllcy8= header-nav-link" title="Séries">
# Séries
# </span></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=251390.html","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Streaming">
# Streaming
# </span></li><li class="header-nav-item"><span class="ACrL3RACryYWlsZXIv header-nav-link" title="Trailers">
# Trailers
# </span></li><li class="header-nav-item"><span class="ACrL2RACr2ZC8= header-nav-link" title="DVD">
# DVD
# </span></li><li class="header-nav-item"><span class="ACrL3ZACrvZC8= header-nav-link" title="VOD">
# VOD
# </span></li><li class="header-nav-item"><span class="ACrL2tACrpZHMv header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-kids","eventLabel":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=251390.html","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" title="Kids">
# Kids
# </span></li><li class="header-nav-item"><span class="ACrL2RACrpc25leS8= header-nav-link-disney header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-disneyplus","eventLabel":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=251390.html","eventAction":"navigation_menu_click","dimension81":"2022-05-10"}' data-ga-trigger="clic" title="Disney+"><i class="header-nav-logo-disney"></i>DISNEY<span class="disney-plus">+</span></span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon compte" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"moviepage"}' data-ga-trigger="clic"><span class="icon icon-profil"></span><img alt="" class="avatar js-myaccount-avatar" src="..."/>
# Mon compte
# </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkZmaWxtJTJGZmljaGVmaWxtX2dlbl9jZmlsbSUzRDI1MTM5MC5odG1s button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout entity movie cf seance-geoloc-redir" data-seance-geoloc-redir="251390" id="content-layout">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Accueil</a><a class="item" href="/film/">Cinéma</a><a class="item" href="/film/aucinema/">Films à l''affiche</a><h1 class="item">
# Doctor Strange in the Multiverse of Madness </h1></div>
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-lg">Doctor Strange in the Multiverse of Madness</div><div class="titlebar-action-holder affinity"><div class="js-affinity-badge" data-entity-id="TW92aWU6MjUxMzkw"></div></div></div>
# <nav class="third-nav third-nav-tab js-third-nav">
# <span class="home item current" href="/film/fichefilm_gen_cfilm=251390.html" title="Fiche film">
# <div class="icon icon-home item-center"></div>
# </span>
# <a class="seance item" href="/seance/film-251390/" id="js-showtimes-nav-redir" title="Séances">
# <div class="icon icon-tickets-seances item-center">Séances</div>
# </a>
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9hY3R1Lw== item" title="News">
# <div class="item-center">News</div>
# </span>
# <a class="trailer item" href="/video/player_gen_cmedia=19595154&amp;cfilm=251390.html" title="Bandes-annonces">
# <div class="icon icon-play-mini item-center">Bandes-annonces</div>
# </a>
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jYXN0aW5nLw== item js-item-mq-medium" title="Casting">
# <div class="item-center">Casting</div>
# </span>
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv item js-item-mq-medium" title="Critiques spectateurs">
# <div class="item-center">Critiques spectateurs</div>
# </span>
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLw== item js-item-mq-medium" title="Critiques presse">
# <div class="item-center">Critiques presse</div>
# </span>
# <span class="item js-item-mq-medium inactive">
# <div class="item-center">VOD</div>
# </span>
# <div class="item-more js-third-sub-nav-holder">
# <span class="item-more-picto icon icon-plus js-trigger-third-nav-sub"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9waG90b3Mv item" title="Photos">
# <div class="item-center">Photos</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Blu-Ray, DVD</div>
# </span>
# <span class="item inactive">
# <div class="item-center">Musique</div>
# </span>
# <a class="item" href="/film/fichefilm-251390/secrets-tournage/" title="Secrets de tournage">
# <div class="item-center">Secrets de tournage</div>
# </a>
# <a class="item" href="/film/fichefilm-251390/box-office/" title="Box Office">
# <div class="item-center">Box Office</div>
# </a>
# <span class="item inactive">
# <div class="item-center">Récompenses</div>
# </span>
# <a class="item" href="/film/fichefilm-251390/similaire/" title="Films similaires">
# <div class="item-center">Films similaires</div>
# </a>
# </div>
# </div>
# </nav>
# <section class="section section-wrap gd-2-cols gd-gap-30">
# <div class="gd-col-left">
# <div class="js-nativebanner ad-nativebanner ad-item" id="dfp-nativebanner"></div>
# <div class="card entity-card entity-card-list cf entity-card-overview">
# <figure class="thumbnail">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MTU0JmNmaWxtPTI1MTM5MC5odG1s thumbnail-container thumbnail-link" title="Bande-annonce Doctor Strange in the Multiverse of Madness">
# <img alt="Bande-annonce Doctor Strange in the Multiverse of Madness" class="thumbnail-img" height="420" src="https://fr.web.img3.acsta.net/c_310_420/pictures/22/04/08/10/30/1779137.jpg" width="310"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="ACrL2ZACrpbG0vYWdlbmRhL3NlbS0yMDIyLTA1LTA0Lw== date blue-link">
# 4 mai 2022
# </span>
# <strong>
# en salle
# </strong>
# <span class="spacer">/</span>
# 2h 06min
# <span class="spacer">/</span>
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDEyLw==">Fantastique</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI1Lw==">Action</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">De</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0zNTU2Lmh0bWw= blue-link">Sam Raimi</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">Par</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT01OTg1Ny5odG1s blue-link">Stan Lee</span>,
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT04MDI1NzcuaHRtbA== blue-link">Michael Waldron</span>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xNjQ0MjcuaHRtbA==">Benedict Cumberbatch</span>,
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT00NTU4NzAuaHRtbA==">Elizabeth Olsen</span>,
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT01NTc1Ny5odG1s">Chiwetel Ejiofor</span>
# </div>
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MTU0JmNmaWxtPTI1MTM5MC5odG1s button button-sm button-primary-full" data-ga='{"hitType":"event","eventCategory":"trailer","eventAction":"clic","eventLabel":"trailer_button","dimension82":"251390-doctor_strange_in_the_multiverse_of_madness","dimension10":"moviepage"}' data-ga-non-interaction="1" data-ga-trigger="clic">
# <span class="txt">Bande-annonce</span>
# </span>
# <span class="ACrL3NACrlYW5jZS9maWxtLTI1MTM5MC8= button button-sm button-inverse-full">
# <span class="txt">Séances (851)</span>
# </span>
# <div class="js-nativebutton ad-nativebutton ad-item" id="dfp-nativebutton"></div>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLw== rating-title"> Presse </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,1</span><span class="stareval-review light"> 24 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv rating-title"> Spectateurs </span>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">3,8</span><span class="stareval-review light"> 2906 notes dont 316 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjUxMzkw" data-size="medium" data-title="Mes amis ">
# <a class="rating-title" href="#">Mes amis </a>
# <div class="stareval stareval-medium stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# </div>
# <div class="bam-container"><div class="bam-cell bam-rating-user"><span class="user-rating-title">noter :</span><div class="js-user-rating js-tooltip-rating-booster" data-entity-id="TW92aWU6MjUxMzkw" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="Envie de voir" data-entity-id="TW92aWU6MjUxMzkw" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">Envie de voir</span></div><div class="bam-cell bam-review js-user-review-link" data-classes="button icon icon-pen" data-content="Rédiger ma critique" data-entity-id="TW92aWU6MjUxMzkw"><span class="button icon icon-pen">Rédiger ma critique</span></div><div class="bam-cell bam-share"><div class="more-overlay js-more-overlay"><div class="more-overlay-trigger js-more-overlay-button"><div class="icon icon-3dots"></div></div><div class="more-overlay-content"><ul class="more-overlay-subcontent"><li class="more-overlay-item icon icon-add-to-collections js-add-to-collection" data-entity-id="TW92aWU6MjUxMzkw">Ajouter à une collection</li></ul><span aria-label="Partager ce contenu sur Whatsapp" class="ACraHRACr0cHM6Ly9hcGkud2hhdHNhcHAuY29tL3NlbmQ/dGV4dD1odHRwcyUzQSUyRiUyRnd3dy5hbGxvY2luZS5mciUyRmZpbG0lMkZmaWNoZWZpbG1fZ2VuX2NmaWxtJTNEMjUxMzkwLmh0bWw= button button-whatsapp-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-whatsapp","clicked_movie_id":251390,"movie_distributor":24110}'><span class="txt">Partager sur WhatsApp</span></span><span aria-label="Partager ce contenu sur Facebook" class="... button button-fb-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-facebook","clicked_movie_id":251390,"movie_distributor":24110}'><span class="txt">Partager sur Facebook</span></span><span aria-label="Partager ce contenu sur Twitter" class="ACraHRACr0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ/dGV4dD1Eb2N0b3IlMjBTdHJhbmdlJTIwaW4lMjB0aGUlMjBNdWx0aXZlcnNlJTIwb2YlMjBNYWRuZXNzJnVybD1odHRwcyUzQSUyRiUyRnd3dy5hbGxvY2luZS5mciUyRmZpbG0lMkZmaWNoZWZpbG1fZ2VuX2NmaWxtJTNEMjUxMzkwLmh0bWwmdmlhPWFsbG9jaW5l button button-tw-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-twitter","clicked_movie_id":251390,"movie_distributor":24110}'><span class="txt">Partager sur Twitter</span></span></div></div></div></div>
# <div class="js-affinity-suggestions" data-entity-id="TW92aWU6MjUxMzkw"></div>
# <div class="js-nativevod ad-nativevod ad-item" id="dfp-nativevod"></div>
# <section class="section ovw ovw-synopsis" id="synopsis-details">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md">Synopsis</h2></div>
# <div class="content-txt">
# Dans ce nouveau film Marvel Studios, l’univers cinématographique Marvel déverrouille et repousse les limites du multivers encore plus loin. Voyagez dans l’inconnu avec Doctor Strange, qui avec l’aide d’anciens et de nouveaux alliés mystiques, traverse les réalités hallucinantes et dangereuses du multivers pour affronter un nouvel adversaire mystérieux.
# </div>
# <div id="mobile-referrer-atf"></div>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3NACrlYW5jZS9maWxtLTI1MTM5MC8= titlebar-link">Séances</span></h2></div>
# <div class="mdl-more gd small-crop">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-115755/" title="Paris">
# Paris
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-87914/" title="Marseille">
# Marseille
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-85327/" title="Nice">
# Nice
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-113315/" title="Lyon">
# Lyon
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-96943/" title="Bordeaux">
# Bordeaux
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-115768/" title="Paris 13e arrondissement">
# Paris 13e arrondissement
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-110514/" title="Clermont-Ferrand">
# Clermont-Ferrand
# </a>
# </li>
# </ul>
# <div class="gd-span-l-4-9 gd-span-m-4-9">
# <div class="more-trigger js-more-trigger" id="more-ovw-theaters">Voir plus de villes</div>
# <div class="row more-hidden gd gd-m-2 gd-l-2">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-85268/" title="Cannes">
# Cannes
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-95171/" title="Brest">
# Brest
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-111337/" title="Pau">
# Pau
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-119251/" title="Avignon">
# Avignon
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-120079/" title="Limoges">
# Limoges
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-121349/" title="Brétigny-sur-Orge">
# Brétigny-sur-Orge
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-95640/" title="Nîmes">
# Nîmes
# </a>
# </li>
# </ul>
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-97612/" title="Montpellier">
# Montpellier
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-100691/" title="Saint-Étienne">
# Saint-Étienne
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-112664/" title="Strasbourg">
# Strasbourg
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-113016/" title="Mulhouse">
# Mulhouse
#  </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-115761/" title="Paris 6e arrondissement">
# Paris 6e arrondissement
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-116312/" title="Rouen">
# Rouen
# </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-251390/pres-de-116648/" title="Chessy">
# Chessy
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </section>
# <div class="js-nativebannerope ad-nativebannerope ad-item" id="dfp-nativebanner-ope"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/videos/fichefilm-251390/toutes/">Bande-annonce</a></h2></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Doctor Strange in the Multiverse of Madness Bande-annonce VO" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_208_117/videothumbnails/21/12/23/09/43/4687929.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:09</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTE5NTk1MTU0JmNmaWxtPTI1MTM5MC5odG1s meta-title-link">Doctor Strange in the Multiverse of Madness Bande-annonce VO</span>
# </div>
# <div class="meta-sub light">
# <span>127 310 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Doctor Strange in the Multiverse of Madness Bande-annonce VF" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_208_117/videothumbnails/21/12/23/09/44/0084102.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:08</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=19595157&amp;cfilm=251390.html">Doctor Strange in the Multiverse of Madness Bande-annonce VF</a>
# </div>
# <div class="meta-sub light">
# <span>10 319 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Doctor Strange in the Multiverse of Madness Bande-annonce (2) VO" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_208_117/videothumbnails/22/02/14/09/55/0769237.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:16</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=19595676&amp;cfilm=251390.html">Doctor Strange in the Multiverse of Madness Bande-annonce (2) VO</a>
# </div>
# <div class="meta-sub light">
# <span>29 568 vues</span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div id="mobile-referrer-mtf"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3ZACrpZGVvcy9maWNoZWZpbG0tMjUxMzkwL3RvdXRlcy8= titlebar-link">Interviews, making-of et extraits</span></h2></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt='Fanzone N°806 - "Spider-Man", "Black Widow", "Les Éternels"... Y a quoi après "Avengers 4" chez Marvel ?' class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_208_117/videothumbnails/19/04/29/15/30/3291407.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">8:04</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3ZpZGVvLTE5NTgzNjY0Lw== meta-title-link">Fanzone N°806 - "Spider-Man", "Black Widow", "Les Éternels"... Y a quoi après "Avengers 4" chez Marvel ?</span>
# </div>
# <div class="meta-sub light">
# <span>169 395 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Fanzone N°819 - Doctor Strange, Thor, Loki... Marvel dévoile sa Phase IV au Comic-Con" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_208_117/videothumbnails/19/07/25/16/52/1813085.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">11:33</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3ZpZGVvLTE5NTg1MDI1Lw== meta-title-link">Fanzone N°819 - Doctor Strange, Thor, Loki... Marvel dévoile sa Phase IV au Comic-Con</span>
# </div>
# <div class="meta-sub light">
# <span>77 323 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="Fanzone N°858 - Doctor Strange cherche réalisateur" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_208_117/videothumbnails/20/01/13/17/33/1933250.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:01</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3ZpZGVvLTE5NTg3MjYxLw== meta-title-link">Fanzone N°858 - Doctor Strange cherche réalisateur</span>
# </div>
# <div class="meta-sub light">
# <span>2 198 vues</span>
# </div>
# </div>
# </div>
# </div>
# <span class="ACrL3ZACrpZGVvcy9maWNoZWZpbG0tMjUxMzkwL3RvdXRlcy8= end-section-link" title="8 vidéos">8 vidéos</span>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9hY3R1Lw== titlebar-link">Dernières news</span></h2></div>
# <div class="hred">
# <div class="card news-card news-card-full cf"><figure class="thumbnail"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xODcwOTQ5MS5odG1s thumbnail-container thumbnail-link" title="Doctor Strange 2 : qui est Sam Raimi, le réalisateur du film Marvel et légende du cinéma d'horreur ?"><img alt="Doctor Strange 2 : qui est Sam Raimi, le réalisateur du film Marvel et légende du cinéma d'horreur ?" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_640_360/newsv7/22/05/06/10/44/4435736.jpg" height="360" src="..." width="640"/></span></figure><div class="meta"><div class="meta-category">NEWS - Stars</div><div class="meta-date">lundi 9 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709491.html">Doctor Strange 2 : qui est Sam Raimi, le réalisateur du film Marvel et légende du cinéma d'horreur ?</a></div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Doctor Strange 2 charcuté ? 30 minutes auraient été coupées !" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/22/05/09/12/03/1049235.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Sorties ciné</div><div class="meta-date">lundi 9 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709553.html">Doctor Strange 2 charcuté ? 30 minutes auraient été coupées !</a></div><div class="meta-body">Selon Sam Raimi, son premier montage de Doctor Strange in the Multiverse of Madness était beaucoup plus long que la version…</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Doctor Strange 2 : de quel univers vient America Chavez ?" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_400_225/newsv7/22/05/04/12/10/2811922.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Sorties ciné</div><div class="meta-date">lundi 9 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709404.html">Doctor Strange 2 : de quel univers vient America Chavez ?</a></div><div class="meta-body">Doctor Strange in the Multiverse of Madness introduit un nouveau personnage, America Chavez, venu d'un monde inconnu et…</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Quiz Marvel : connaissez-vous les véritables noms des Avengers ?" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/newsv7/22/05/06/14/10/0711043.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Culture ciné</div><div class="meta-date">dimanche 8 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709249.html">Quiz Marvel : connaissez-vous les véritables noms des Avengers ?</a></div><div class="meta-body">Alors que "Doctor Strange" est diffusé ce soir sur TF1, testez vos connaissances sur les patronymes des personnages qui…</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="Doctor Strange 2 : sur quelle Terre évoluent les héros du MCU ?" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/newsv7/22/05/06/09/18/1248131.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">NEWS - Sorties ciné</div><div class="meta-date">dimanche 8 mai 2022</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=18709500.html">Doctor Strange 2 : sur quelle Terre évoluent les héros du MCU ?</a></div><div class="meta-body">Doctor Strange in the Multiverse of Madness, actuellement en salles, contient son lot de références aux comics Marvel, parmi…</div></div></div> </div>
# <a class="end-section-link" href="/film/fichefilm-251390/actu/" title="116 news sur ce film">116 news sur ce film</a>
# </section>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jYXN0aW5nLw== titlebar-link">Acteurs et actrices</span></h2></div>
# <div class="gd gd-gap-20 gd-xs-2 gd-s-4">
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xNjQ0MjcuaHRtbA== thumbnail-container thumbnail-link" title="Benedict Cumberbatch">
# <img alt="Benedict Cumberbatch" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/14/06/05/09/54/019769.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=164427.html">Benedict Cumberbatch</a>
# </div>
# <div class="meta-sub light">
# Rôle : Dr. Stephen Strange
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT00NTU4NzAuaHRtbA== thumbnail-container thumbnail-link" title="Elizabeth Olsen">
# <img alt="Elizabeth Olsen" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_162_216/pictures/15/09/15/12/25/231241.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=455870.html">Elizabeth Olsen</a>
# </div>
# <div class="meta-sub light">
# Rôle : Wanda Maximoff / Scarlet Witch
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT01NTc1Ny5odG1s thumbnail-container thumbnail-link" title="Chiwetel Ejiofor">
# <img alt="Chiwetel Ejiofor" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_162_216/pictures/15/09/28/11/12/007562.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=55757.html">Chiwetel Ejiofor</a>
# </div>
# <div class="meta-sub light">
# Rôle : Mordo
# </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT04MTIyMy5odG1s thumbnail-container thumbnail-link" title="Benedict Wong">
# <img alt="Benedict Wong" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/16/10/21/16/05/442276.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=81223.html">Benedict Wong</a>
# </div>
# <div class="meta-sub light">
# Rôle : Wong
# </div>
# </div>
# </div>
# </div>
# <a class="end-section-link" href="/film/fichefilm-251390/casting/" title="Casting complet et équipe technique">Casting complet et équipe technique</a>
# </section>
# <div id="mobile-referrer-btf"></div>
# <section class="section ovw">
# <div class="titlebar"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLw== titlebar-link">Critiques Presse</span></h2></div>
# <div class="row reviews-press-list gd gd-xs-1 gd-m-2">
# <ul class="item-holder">
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODUx stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODUx stareval-link stareval-link-info js-anchor-link">20 Minutes</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODIx stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODIx stareval-link stareval-link-info js-anchor-link">CNews</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODkw stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODkw stareval-link stareval-link-info js-anchor-link">Dernières Nouvelles d'Alsace</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODU1 stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODU1 stareval-link stareval-link-info js-anchor-link">Ecran Large</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODc3 stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODc3 stareval-link stareval-link-info js-anchor-link">Filmsactu</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODMw stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5ODMw stareval-link stareval-link-info js-anchor-link">IGN France</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5OTg2 stareval-link" title="Très bien"><div class="rating-mdl n40 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTM5MC9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzQwMDk5OTg2 stareval-link stareval-link-info js-anchor-link">LCI</span></div>
# </li>
# <li class="item">
# ...
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-nativebanner","dfp-nativebutton","dfp-nativevod","dfp-nativebanner-ope","dfp-atf","dfp-atf","dfp-mtf","dfp-mtf","dfp-autopromo","dfp-autopromo","dfp-btf","dfp-btf","dfp-pulse"];
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"cc2b8ddf7a8e8801f75337020920fec3c72a477b","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min-755b0d7e3c.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min-760736ff24.css"},"images":{"logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine-7e88ee87c5.svg","bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson-e492ec8e56.gif","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously-ffccba6479.gif","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle-5d973cbbc2.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found-dec1f46fbc.gif","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster-7c731e1347.png","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles-766780d2bf.png","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding-a32c4541a1.png","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions-0009180ea0.png","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron-363298eee7.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":"wads","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-PL6PBF","analyticsUACode":"UA-597605-13","analyticsPartners":[],"reCaptchaSiteKey":"6Les8ukZAAAAACSRJMDHQqUcD2iwl1wGq1or2g4S"},"disqus":{"shortname":"allocine-prod2","apiKey":"WmFI6FIX8lZxK1fZdaYuGxizFUoFfJn3iCHfRulxsPNMQOfZwDWbnD0xyjS6fqSR","ssoButton":"https:\/\/fr.web.img1.acsta.net\/commons\ ...
#     AC.routing = {"base_url":"","routes":{"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_migration":"deno","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["variable","-","\\d+","localization",true],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","day":0,"_brand":"allocine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/"],["variable","","(?:\/d-(?P<day>[0-9]{1,2}))?","filters_0",true],["text","\/favoris\/seances"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","day":0,"_brand":"allocine","filters_0":"","filters_0_order":{"day":"d"},"filters_defaults":{"day":0},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"filters_0":"(\/d-(?P<day>[0-9]{1,2}))?","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia",true],["text","\/video\/player_gen_cmedia"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_migration":"deno","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/videos\/fichefilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::allVideosTrailer ...
#     AC.route = 'moviepage';
# }(window));
# </script>
# <script src="https://assets.allocine.fr/js/website/translations-b711c990e5af597dbe10279815cd0a52.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.93bf89cf686ddeb87612.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/moviepage.9db4c2f6dc1663fc8d35.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"moviepage","site_section":"movie","movie_id":251390,"movie_label":"doctor_strange_in_the_multiverse_of_madness","movie_isshowtime":1,"movie_distributors":24110,"genre":"13012=fantastique&13025=action&13001=aventure","releasedate":"2022-05-04","coming_soon":0,"actor":"164427,455870,55757,81223,900680,81263,163572,862322,885705,851756,745695,690,11461","actor_voice":"","actor_local_voice":"","director":"3556","nationality":"5002","press_rating":3.2,"user_rating":3.9,"is_netflix":0,"is_amazon":0,"is_disney":0,"is_mycanal":0,"is_svod_originals":0,"is_svod_exclusive":0,"company":[68,24110,28041],"svod_providers":[],"vod_providers":[],"tags":[5275,428,1108,1495,1509,2512,2700,2719,2781,5105,5128,5228,5235,5238,5271,5324,5946,5948,6018,6068,5291]}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"TW92aWU6MjUxMzkw":{"id":"TW92aWU6MjUxMzkw","title":"Doctor Strange in the Multiverse of Madness","social":{"user_note_i_want_to_see_count":9788},"flags":{"isComingSoon":false},"releaseDate":"2022-05-04T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjE5MTAxNDM=","internalId":21910143,"url":"https:\/\/fr.web.img5.acsta.net\/pictures\/22\/04\/08\/10\/30\/1779137.jpg","path":"\/pictures\/22\/04\/08\/10\/30\/1779137.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"U.S.A."}]}};
#         </script>
# <script type="application/ld+json">
# {
#     "@context":"https://schema.org",
#     "@type":"Movie",
#     "name":"Doctor Strange in the Multiverse of Madness",
#     "image": {
#         "@type": "ImageObject",
#         "url": "https://fr.web.img5.acsta.net/pictures/22/04/08/10/30/1779137.jpg"
#     }
#         ,
#     "duration": "PT02H06M00S"
#             ,
#     "genre": [
#             "Fantastique",
#                 "Action",
#                 "Aventure"
#             ]
#             ,
#     "description": "Dans ce nouveau film Marvel Studios, l’univers cinématographique Marvel déverrouille et repousse les limites du multivers encore plus loin. Voyagez dans l’inconnu avec Doctor Strange, qui avec l’aide d’anciens et de nouveaux alliés mystiques, traverse les réalités hallucinantes et dangereuses du multivers pour affronter un nouvel adversaire mystérieux."
#             ,
#     "director": {
#         "@type": "Person",
#                 "url": "https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=3556.html",
#                 "name": "Sam Raimi"
#     }
#             ,
#             "actor": [
#         {
#     "@type": "Person",
#         "url": "https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=164427.html",
#         "name": "Benedict Cumberbatch"
#         },
#             {
#     "@type": "Person",
#         "url": "https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=455870.html",
#         "name": "Elizabeth Olsen"
#         },
#             {
#     "@type": "Person",
#         "url": "https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=55757.html",
#         "name": "Chiwetel Ejiofor"
#         },
#             {
#     "@type": "Person",
#         "url": "https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=81223.html",
#         "name": "Benedict Wong"
#         }
#             ]
#             ,
#     "creator": [
#         {
#     "@type": "Person",
#     "name": "Michael Waldron"
#         },
#             {
#     "@type": "Person",
#     "name": "Scott Derrickson"
#         },
#             {
#     "@type": "Person",
#     "name": "C. Robert Cargill"
#         },
#             {
#     "@type": "Person",
#     "name": "Jon Spaihts"
#         },
#             {
#     "@type": "Person",
#     "name": "Jade Bartlett"
#         },
#             {
#     "@type": "Person",
#     "name": "Stan Lee"
#         },
#             {
#     "@type": "Person",
#     "name": "Steve Ditko"
#         }
#             ]
#             ,
#     "musicBy": [
#         {
#     "@type": "Person",
#     "name": "Danny Elfman"
#         },
#             {
#     "@type": "Person",
#     "name": "Dave Jordan"
#         }
#             ]
#             ,
#     "trailer": {
#         "@type": "VideoObject",
#         "name": "Doctor Strange in the Multiverse of Madness Bande-annonce VO",
#         "description": "Doctor Strange in the Multiverse of Madness Bande-annonce VO",
#         "thumbnailUrl": "https://fr.web.img6.acsta.net/videothumbnails/21/12/23/09/43/4687929.jpg",
#         "thumbnail": {
#             "@type": "ImageObject",
#             "contentUrl": "https://fr.web.img6.acsta.net/videothumbnails/21/12/23/09/43/4687929.jpg"
#         },
#                 "uploadDate": "2021-12-22",
#                 "duration": "PT00H02M09S",
#         "embedUrl": "https://player.allocine.fr/19595154.html",
#         "url": "https://www.allocine.fr/video/player_gen_cmedia=19595154&amp;cfilm=251390.html"
#     }
#             ,
#     "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "3,8",
#         "ratingCount": "2906",
#                 "reviewCount": "316",
#                 "bestRating": "5",
#         "worstRating": "0,5"
#     }
#     }
# </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min\u002D19a7f529a7.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# </html>

# %% [markdown]
# For title
# ```html
# <div class="titlebar-title titlebar-title-lg">Le Grand Bain</div>
# ```
# For the synopsis
#
# ```html
# <div class="content-txt " itemprop="description"
#
#
#               C’est dans les couloirs de leur piscine municipale que Bertrand, Marcus, Simon, Laurent, Thierry et les autres s’entraînent sous l’autorité toute relative de Delphine, ancienne gloire des bassins. Ensemble, ils se sentent libres et utiles. Ils vont mettre toute leur énergie dans une discipline jusque-là propriété de la gent féminine : la natation synchronisée. Alors, oui c’est une idée plutôt bizarre, mais ce défi leur permettra de trouver un sens à leur vie...
#
#       </div>
# ```

# %%
for elem in soup.find_all("div", attrs={"class": "titlebar-title titlebar-title-lg"}):
    # Just like that
    print(elem.text)

for elem in soup.find_all("div", attrs={"class": "content-txt "}):
    # Just like that
    print(elem.text)
# Out:
# Doctor Strange in the Multiverse of Madness

# %% [markdown]
# 1) Automate this script for the entire list of movies.
#
# 2) Put the information in three lists (`film_links`, `title`, `synopsis`).
#
# 3) Create a `DataFrame` object from the `pandas` library that you will have to install. This dataframe will have to include these three informations in three columns.
#
# 4) Save this dataframe in a CSV file.
#
# And here's your first real scrap, you're real hackers now.

# %%
import time
import random
from random import randint

title = []
synopsis = []
film_links=[]
# Here are the things you will have to do for all links:
# - Slow down the frequency of requests to avoid being identified and therefore banned from the website.
# Use `time.sleep(random.uniform(1.0, 2.0))`
# - Get request object from URL
# - Extract the content into a variable using BeautifulSoup
# - Get title
# - Get synopsis

# Check the length of the lists before creating the dataframe
len(title), len(synopsis), len(movie_links)

# %%
import time
import random
from random import randint

title = []
synopsis = []
film_links=[]
# Here are the things you will have to do for all links:
# - Slow down the frequency of requests to avoid being identified and therefore banned from the website.
# Use `time.sleep(random.uniform(1.0, 2.0))`
# - Get request object from URL
# - Extract the content into a variable using BeautifulSoup
# - Get title
# - Get synopsis

# Check the length of the lists before creating the dataframe
len(title), len(synopsis), len(movie_links)

# %%
import pandas as pd

df = pd.DataFrame({"Title": title})
df["Synopsis"] = synopsis
df["Links"] = movie_links

# %%
df.to_csv("./assets/allo_cine.csv", index=False)
